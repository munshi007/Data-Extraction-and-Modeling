# %% [markdown]
# Crawl events (date, time, location, title, artists, works and image link) from the following link: https://www.lucernefestival.ch/en/program/summer-festival-23.
#
# Insert data into a database (PostgreSQL), with a self-defined schema

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# Out:
# /var/folders/gy/sfq3f6894rd1v__jp0ggg92c0000gn/T/ipykernel_9333/1222050232.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
URL = 'https://www.lucernefestival.ch/en/program/summer-festival-24'

# %%
# HTTP Request
webpage = requests.get(URL)

# %%
webpage
# Out:
# <Response [200]>

# %%
# Soup Object containiang all data
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Summer Festival 2024 | Lucerne Festival</title>
# <meta content="None" name="description"/>
# <meta content="MIR MEDIA - Digital Agency - www.mir.de" name="author"/>
# <meta content="index, follow" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/>
# <link href="/static/css/lib/daterangepicker.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.jsdelivr.net/npm/@fancyapps/ui/dist/fancybox.css" rel="stylesheet"/>
# <link href="/static/css/build/app.min.css" rel="stylesheet" type="text/css"/>
# <link href="/static/images/favicons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/static/images/favicons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/static/images/favicons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/static/images/favicons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/static/images/favicons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/static/images/favicons/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/static/images/favicons/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/static/images/favicons/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/static/images/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/static/images/favicons/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/static/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/static/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/static/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/static/images/favicons/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/static/images/favicons/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <!-- OG TAGS -->
# <meta content="https://www.lucernefestival.ch/en/program/summer-festival-24" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="" property="og:title"/>
# <meta content="None" property="og:description"/>
# <meta content="" property="og:image"/>
# <meta content="" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="None" name="twitter:description"/>
# <!-- END OF OG TAGS -->
# <script language="javascript">
# 		var DjangoApp = {
# 			settings: {
# 				STATIC_URL: "/static/",
# 				TRANSLATIONS: {
# 					LOG_OUT: "Ausloggen",
# 				},
# 			},
# 			festival: {
# 				start: "13.08.2024",
# 				end: "15.09.2024",
# 				selected_start: "13.08.2024",
# 				selected_end: "15.09.2024"
# 			}
# 		}
# 		window.document.searchAutocompleteUrl = '/en/search/api/search/autocomplete/';
# 		window.document.searchResultsUrl = '/en/search';
# 	</script>
# <!-- Google Tag Manager -->
# <div data-cookie-consent="googleTagManager">
# <!--if-consent
# 		<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-K4N3C53');</script>
# 		endif-->
# </div>
# <!-- End Google Tag Manager -->
# <!-- Google Tag Manager -->
# <div data-cookie-consent="youtube">
# <!--if-consent
# 		<script src="https://www.youtube.com/iframe_api"></script>
# 		endif-->
# </div>
# <!-- End Google Tag Manager -->
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <div data-cookie-consent="googleTagManager">
# <!--if-consent
# 			<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-K4N3C53" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# 		endif-->
# </div>
# <!-- End Google Tag Manager (noscript) -->
# <div class="page-container event-list-page">
# <div aria-hidden="true" class="placeholder-header-sticky"></div>
# <header class="main-header-container">
# <div class="main-header transparent">
# <div class="grid-container fluid">
# <div class="grid-x grid-margin-x align-justify align-middle">
# <div class="cell shrink reset">
# <a class="logo" href="/en/">Lucerne Festival</a>
# </div>
# <div class="cell shrink">
# <ul class="head-item top-menu menu-1 show-for-xlarge">
# <li>
# <a class="link-secondary" href="/en/tickets/program">Program and Tickets</a>
# </li>
# <li>
# <a class="link-secondary" href="/en/ihr_engagement">Your Commitment</a>
# </li>
# <li>
# <a class="link-secondary" href="/en/magazine">Magazine</a>
# </li>
# </ul>
# <ul class="menu-additional menu-additional-top show-for-xlarge">
# <li class="menu-additional__item" data-additional="search">
# <a class="menu-additional__link open-search" href="/en/search">
# <svg class="menu-additional__icon" fill="none" height="20" viewbox="0 0 21 20" width="21" xmlns="http://www.w3.org/2000/svg"><path d="
.065H3.72a1.22 1.22 0 01-.856-.282c-.24-.2-.397-.485-.44-.798l.582-10.307c0-.06.023-.118.065-.16a.222.222 0 01.158-.067h.893v.699c0 .262.103.514.285.699a.966.966 0 001.378 0 .997.997 0 00.285-.7v-.698h4.252v.699c0 .26.102.51.282.696.181.185.426.29.683.293a.966.966 0 00.683-.293.997.997 0 00.282-.696V6.45h.482a.194.194 0 01.161.073.28.28 0 01.072.217l.58 10.226c-.05.317-.218.602-.469.798-.25.195-.565.286-.88.254v.046z" fill="#000"></path></svg>
# <strong basket-number="" class="menu-additional__basket-number">0</strong>
# </a>
# </li>
# <li aria-expanded="false" class="menu-additional__item" data-additional="account">
# <button class="menu-additional__link menu-additional__toggle" id="account-toggle" type="button">
# <span>My account</span>
# <svg class="menu-additional__icon" fill="none" height="20" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M5.329 12.1a1.035 1.035 0 00-.79.15 8.065 8.065 0 00-2.6 2.905 8.14 8.14 0 00-.943 3.795 1.057 1.057 0 00.305.743 1.04 1.04 0 00.736.307c.277 0 .541-.11.737-.307.195-.197.305-.464.305-.743a5.998 5.998 0 01.697-2.816 5.943 5.943 0 011.934-2.15 1.041 1.041 0 00.27-1.425 1.028 1.028 0 00-.651-.46zm8.116.131a1.043 1.043 0 00-.781-.14 1.018 1.018 0 00-.651.459c-.15.232-.204.515-.149.787.059.266.22.498.446.646a5.973 5.973 0 011.92 2.156 6.02 6.02 0 01.693 2.811A1.052 1.052 0 0015.964 20c.274-.005.535-.117.728-.314.192-.196.302-.46.304-.736a8.149 8.149 0 00-.943-3.806 8.074 8.074 0 00-2.608-2.913zM14.766 5.8a5.825 5.825 0 00-1.685-4.1A5.732 5.732 0 009.01 0C7.484 0 6.02.611 4.94 1.699a5.825 5.825 0 00-1.685 4.102c0 1.538.607 3.014 1.686 4.102a5.732 5.732 0 004.07 1.699A5.741 5.741 0 0013.077 9.9a5.834 5.834 0 001.688-4.1zM9.02 9.55a3.697 3.697 0 01-2.078-.61 3.741 3.741 0 01-1.39-1.672 3.776 3.776 0 01.776-4.1 3.691 3.691 0 014.058-.834 3.725 3.725 0 011.677 1.38c.41.617.63 1.344.63 2.087a3.764 3.764 0 01-1.09 2.604A3.704 3.704 0 019.02 9.503v.046z" fill="#000"></path></svg>
# </button>
# <aside class="menu-additional__aside">
# <span class="menu-additional__name"><a account-name="" class="link-secondary" href="https://shop.lucernefestival.ch/account"></a></span>
# <a account-button="" class="button menu-additional__button" href="https://shop.lucernefestival.ch/account" title="Log in">Log in</a>
# </aside>
# </li>
# <li aria-expanded="false" class="menu-additional__item" data-additional="language">
# <button class="menu-additional__link menu-additional__toggle" id="language-toggle" type="button">
# <span class="lang link-secondary">en</span>
# <svg fill="none" height="5" viewbox="0 0 9 5" width="9" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.24609 0.75L4.99609 4.25L1.74609 0.75" stroke="black" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path>
# </svg>
# </button>
# <ul class="menu-additional__aside">
# <li class="language-option">
# <a class="link-secondary" href="/de/programm/sommer-festival-2024" hreflang="de">
#                 Deutsch
#             </a>
# </li>
# <li class="language-option language-option--active">
# <a class="link-secondary" href="/en/program/summer-festival-24" hreflang="en">
#                 English
#             </a>
# </li>
# </ul>
# </li>
# </ul>
# <div class="head-item menu-container overlay-container">
# <button class="open-menu open-overlay burger">
# <span class="caption">Menü <span class="show-for-sr">öffnen</span></span>
# <span class="bar bar-1"></span>
# <span class="bar bar-2"></span>
# <span class="bar bar-3"></span>
# </button>
# <nav aria-label="Main menu" class="main-menu overlay-content" role="navigation">
# <ul class="menu-additional menu-additional-burger hide-for-xlarge">
# <li class="menu-additional__item" data-additional="search">
# <a class="menu-additional__link open-search" href="/en/search">
# <svg class="menu-additional__icon" fill="none" height="20" viewbox="0 0 21 20" width="21" xmlns="http://www.w3.org/2000/svg"><path d="M20.6974 18.2001L14.6028 12.1019C15.6252 10.7378 16.157 9.06805 16.112 7.36357C16.0669 5.65909 15.4475 4.01985 14.3544 2.71181C13.2613 1.40377 11.7585 0.503639 10.0899 0.1575C8.42131 -0.188638 6.68477 0.0395031 5.16203 0.804907C3.63929 1.57031 2.41968 2.82809 1.70108 4.37415C0.982475 5.92022 0.807056 7.66385 1.20325 9.32221C1.59944 10.9806 2.54401 12.4563 3.88372 13.5101C5.22343 14.5638 6.87967 15.1337 8.58374 15.1273V15.1273C10.2204 15.1246 11.812 14.5904 13.1193 13.6051L19.2045 19.6844C19.3006 19.7842 19.4158 19.8636 19.5432 19.9178C19.6707 19.972 19.8077 20 19.9462 20C20.0847 20 20.2218 19.972 20.3492 19.9178C20.4767 19.8636 20.5919 19.7842 20.688 19.6844C20.8853 19.486 20.9961 19.2174 20.9961 18.9375C20.9961 18.6576 20.8853 18.3891 20.688 18.1906L20.6974 18.2001ZM12.4484 11.4306C11.9434 11.9388 11.3426 12.3417 10.6808 12.616C10.019 12.8903 9.30945 13.0305 8.59317 13.0284C7.14968 13.0284 5.76532 12.4546 4.74462 11.4333C3.72393 10.412 3.15053 9.02689 3.15053 7.58256C3.15053 6.13824 3.72393 4.75306 4.74462 3.73177C5.76532 2.71047 7.14968 2.13671 8.59317 2.13671V2.13671C9.30826 2.13546 10.0166 2.27547 10.6775 2.5487C11.3384 2.82194 11.9389 3.22303 12.4445 3.72897C12.9502 4.23491 13.351 4.83575 13.6241 5.49703C13.8972 6.15831 14.0371 6.86706 14.0358 7.58256C14.0395 8.29725 13.901 9.00551 13.6284 9.66614C13.3559 10.3268 12.9548 10.9265 12.4484 11.4306V11.4306Z" fill="black"></path></svg>
# <span class="show-for-sr">Suche öffnen</span>
# </a>
# <!-- <label class="menu-additional__link open-search" for="search-field">
#
#     </label> -->
# </li>
# <li class="menu-additional__item" data-additional="basket">
# <a class="menu-additional__link menu-additional__link--basket" href="https://shop.lucernefestival.ch/cart/shoppingCart" title="Cart">
# <svg class="menu-additional__icon" fill="none" height="20" width="16" xmlns="http://www.w3.org/2000/svg"><path d="M14.898 6.687c0-.585-.23-1.146-.636-1.559a2.154 2.154 0 00-1.535-.646h-.483V4.11a4.17 4.17 0 00-1.19-2.895A4.043 4.043 0 008.206 0a4.042 4.042 0 00-2.865 1.205 4.17 4.17 0 00-1.2 2.905v.372h-.893c-.565 0-1.106.224-1.51.624-.404.4-.638.945-.652 1.517l-.59 10.362c.05.81.4 1.572.98 2.13.58.56 1.347.875 2.147.882H12.2a3.129 3.129 0 002.286-.859 3.264 3.264 0 001.01-2.253l-.598-10.198zM6.07 4.119c.009-.558.231-1.09.62-1.484.388-.395.912-.62 1.461-.63a1.983 1.983 0 011.501.608 2.114 2.114 0 01.652 1.497v.372H6.072V4.12zM12.2 18.065H3.72a1.22 1.22 0 01-.856-.282c-.24-.2-.397-.485-.44-.798l.582-10.307c0-.06.023-.118.065-.16a.222.222 0 01.158-.067h.893v.699c0 .262.103.514.285.699a.966.966 0 001.378 0 .997.997 0 00.285-.7v-.698h4.252v.699c0 .26.102.51.282.696.181.185.426.29.683.293a.966.966 0 00.683-.293.997.997 0 00.282-.696V6.45h.482a.194.194 0 01.161.073.28.28 0 01.072.217l.58 10.226c-.05.317-.218.602-.469.798-.25.195-.565.286-.88.254v.046z" fill="#000"></path></svg>
# <strong basket-number="" class="menu-additional__basket-number">0</strong>
# </a>
# </li>
# <li aria-expanded="false" class="menu-additional__item" data-additional="account">
# <button class="menu-additional__link menu-additional__toggle" id="account-toggle" type="button">
# <span>My account</span>
# <svg class="menu-additional__icon" fill="none" height="20" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M5.329 12.1a1.035 1.035 0 00-.79.15 8.065 8.065 0 00-2.6 2.905 8.14 8.14 0 00-.943 3.795 1.057 1.057 0 00.305.743 1.04 1.04 0 00.736.307c.277 0 .541-.11.737-.307.195-.197.305-.464.305-.743a5.998 5.998 0 01.697-2.816 5.943 5.943 0 011.934-2.15 1.041 1.041 0 00.27-1.425 1.028 1.028 0 00-.651-.46zm8.116.131a1.043 1.043 0 00-.781-.14 1.018 1.018 0 00-.651.459c-.15.232-.204.515-.149.787.059.266.22.498.446.646a5.973 5.973 0 011.92 2.156 6.02 6.02 0 01.693 2.811A1.052 1.052 0 0015.964 20c.274-.005.535-.117.728-.314.192-.196.302-.46.304-.736a8.149 8.149 0 00-.943-3.806 8.074 8.074 0 00-2.608-2.913zM14.766 5.8a5.825 5.825 0 00-1.685-4.1A5.732 5.732 0 009.01 0C7.484 0 6.02.611 4.94 1.699a5.825 5.825 0 00-1.685 4.102c0 1.538.607 3.014 1.686 4.102a5.732 5.732 0 004.07 1.699A5.741 5.741 0 0013.077 9.9a5.834 5.834 0 001.688-4.1zM9.02 9.55a3.697 3.697 0 01-2.078-.61 3.741 3.741 0 01-1.39-1.672 3.776 3.776 0 01.776-4.1 3.691 3.691 0 014.058-.834 3.725 3.725 0 011.677 1.38c.41.617.63 1.344.63 2.087a3.764 3.764 0 01-1.09 2.604A3.704 3.704 0 019.02 9.503v.046z" fill="#000"></path></svg>
# </button>
# <aside class="menu-additional__aside">
# <span class="menu-additional__name"><a account-name="" class="link-secondary" href="https://shop.lucernefestival.ch/account"></a></span>
# <a account-button="" class="button menu-additional__button" href="https://shop.lucernefestival.ch/account" title="Log in">Log in</a>
# </aside>
# </li>
# <li aria-expanded="false" class="menu-additional__item" data-additional="language">
# <button class="menu-additional__link menu-additional__toggle" id="language-toggle" type="button">
# <span class="lang link-secondary">en</span>
# <svg fill="none" height="5" viewbox="0 0 9 5" width="9" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.24609 0.75L4.99609 4.25L1.74609 0.75" stroke="black" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path>
# </svg>
# </button>
# <ul class="menu-additional__aside">
# <li class="language-option">
# <a class="link-secondary" href="/de/programm/sommer-festival-2024" hreflang="de">
#                 Deutsch
#             </a>
# </li>
# <li class="language-option language-option--active">
# <a class="link-secondary" href="/en/program/summer-festival-24" hreflang="en">
#                 English
#             </a>
# </li>
# </ul>
# </li>
# </ul>
# <button class="close-menu close-overlay button-close" title="Schließen">
# <span class="show-for-sr">close</span>
# </button>
# <div class="menu-wrapper">
# <ul class="accordion-menu menu-1 primary-menu h3" data-accordion-menu="" data-multi-open="false" role="menubar">
# <li>
# <a class="active" href="/en/tickets/program">
# 					Program and Tickets
# 				</a>
# </li>
# <li>
# <a class="" href="/en/ihr_engagement">
# 					Your Commitment
# 				</a>
# </li>
# <li>
# <a class="" href="/en/magazine">
# 					Magazine
# 				</a>
# </li>
# </ul>
# <ul class="accordion-menu menu-1 secondary-menu bold" data-accordion-menu="" data-multi-open="false" role="menubar">
# <li>
# <a class="" href="/en/about-us/lucerne-festival">
# 					Lucerne Festival
# 				</a>
# <ul class="nested menu-2 submenu">
# <li>
# <a class="" href="/en/festival-introduction">
#                                 The Festival
#                             </a>
# </li>
# <li>
# <a class="" href="/en/about-us/history">
#                                 History
#                             </a>
# </li>
# <li>
# <a class="" href="/en/sustainability">
#                                 Sustainability
#                             </a>
# </li>
# <li>
# <a class="" href="/en/about-us/organization">
#                                 Organization
#                             </a>
# </li>
# <li>
# <a class="" href="/en/jobs">
#                                 Jobs
#                             </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="" href="/en/lucerne-festival-Orchestra">
# 					Lucerne Festival Orchestra
# 				</a>
# </li>
# <li>
# <a class="" href="/en/lucerne-festival-contemporary-orchestra">
# 					LFCO &amp; Academy
# 				</a>
# </li>
# <li>
# <a class="" href="/en/on-demand">
# 					Lucerne Festival On Demand
# 				</a>
# </li>
# <li>
# <a class="" href="/en/lucerne-festival-young">
# 					Young Audience
# 				</a>
# </li>
# <li>
# <a class="" href="/en/service">
# 					Service
# 				</a>
# <ul class="nested menu-2 submenu">
# <li>
# <a class="" href="/en/concierge/ticket-sales">
#                                 Ticket Sales
#                             </a>
# </li>
# <li>
# <a class="" href="/en/service/event-venues">
#                                 Event Venues
#                             </a>
# </li>
# <li>
# <a class="" href="/en/service/hotels">
#                                 Hotels
#                             </a>
# </li>
# <li>
# <a class="" href="https://www.lucernefestival.ch/en/magazine/concert-transmissions-2023/284">
#                                 Concert transmissions 2023
#                             </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="" href="/en/shop">
# 					Shop
# 				</a>
# </li>
# </ul>
# <a class="donation-button" href="/en/spenden">
# <svg class="donation-heart" fill="none" height="40" viewbox="0 0 21 19" width="44" xmlns="http://www.w3.org/2000/svg"><path d="M16.1355 1.53361L16.1442 1.53467L16.1529 1.53557C16.6451 1.58638 17.1186 1.75179 17.5354 2.01854C17.9496 2.28362 18.2964 2.64145 18.5483 3.06367C18.9162 3.71537 19.1379 4.43934 19.1981 5.18537C19.2586 5.93468 19.1546 6.68816 18.8934 7.39308L18.8846 7.41691L18.877 7.44117C18.6613 8.12855 18.1059 9.03719 17.2809 10.0824C16.4717 11.1075 15.4653 12.1877 14.4338 13.2114C12.8243 14.8088 11.1882 16.2348 10.2205 17.0518C9.24714 16.2153 7.6064 14.7771 5.9905 13.1677C4.95803 12.1394 3.95047 11.0557 3.13979 10.027C2.31351 8.97845 1.75553 8.06557 1.5373 7.37225L1.53071 7.35134L1.52322 7.33073C1.27005 6.63457 1.17092 5.89177 1.23267 5.15358C1.29431 4.41672 1.51478 3.70197 1.87891 3.05844C2.12769 2.62866 2.47401 2.26336 2.88997 1.99203C3.29282 1.72925 3.75002 1.56176 4.22683 1.50199H4.23154H4.23285H4.23416H4.23547H4.23678H4.23809H4.2394H4.24071H4.24201H4.25249H4.25773H4.26296H4.27344H4.27475H4.27606H4.27868H4.28392H4.29439H4.29963H4.30094H4.30225H4.30487H4.3101H4.31534H4.32582H4.33629H4.35724H4.36772H4.36903H4.37034H4.37164H4.37295H4.37819H4.42009H4.50389H4.81038C5.65206 1.55247 6.47135 1.7938 7.20616 2.20784C7.94864 2.6262 8.58499 3.2097 9.066 3.91322L9.07578 3.92753L9.08605 3.94149C9.17314 4.05984 9.27763 4.16433 9.39598 4.25142L9.40406 4.25736L9.41226 4.26314C9.56235 4.36901 9.73195 4.44405 9.91125 4.48392C10.0905 4.52379 10.276 4.5277 10.4568 4.49541C10.6376 4.46312 10.8102 4.39528 10.9646 4.29582C11.119 4.19636 11.2522 4.06726 11.3564 3.91598L11.3606 3.90978L11.3648 3.90351L11.3651 3.9031C11.368 3.89867 11.3924 3.86121 11.4418 3.79399C11.4951 3.72145 11.5774 3.61444 11.6874 3.48555C11.9087 3.22631 12.2353 2.88677 12.6567 2.56183C13.4998 1.91173 14.6691 1.35623 16.1355 1.53361Z" stroke="black" stroke-miterlimit="10" stroke-width="2"></path></svg>
# <div class="bold">Donate now!</div>
# </a>
# </div>
# </nav>
# <div class="search-overlay">
# <div class="search-overlay-inner">
# <button class="close-search button-close" title="Schließen"><span class="show-for-sr">close</span></button>
# <div class="page-header">
# <div class="grid-container">
# <div class="grid-x grid-margin-x align-center">
# <div class="cell large-8 xxlarge-7">
# <p class="h1 text-center">Search</p>
# <div class="search-dropdown">
# <form action="/en/search?q=" class="search-form custom-form" method="get">
# <div class="search-row relative">
# <input autocomplete="off" class="search-input" id="search-field" name="q" placeholder="Enter search term" type="text"/>
# <button class="search-submit" type="submit"><span class="icon-search-24"></span></button>
# </div>
# <ul class="search-results" id="search-results"></ul>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="grid-container fluid breadcrumbs-container">
# <nav aria-label="Sie befinden sich hier" role="navigation">
# <ul class="breadcrumbs">
# <li>
# <a class="link-secondary" href="/en/">Home</a>
# </li>
# <li class="current">
# <span>
# <span class="show-for-sr">Current page: </span>Program and Tickets
# 					</span>
# </li>
# </ul>
# </nav>
# </div>
# <main class="fl-clr yellow content-container">
# <!-- search_start_1 -->
# <header class="page-header clip-path clr-pri">
# <div class="grid-container">
# <div class="grid-x grid-margin-x">
# <div class="cell">
# <h1>Program and Tickets</h1>
# <span aria-hidden="true"></span>
# </div>
# </div>
# </div>
# <nav class="sub-nav festival-nav">
# <div class="grid-container">
# <div class="grid-x grid-margin-x">
# <div class="cell">
# <ul class="sub-nav-list festival-nav-list">
# <li>
# <a class="sub-nav-item festival-nav-item link-secondary" href="/en/program/spring-festival-24">
# <h2 class="wrap">
# <span class="h4">Spring Festival 2024</span>
# <span class="preline">22.03.-24.03.2024</span>
# </h2>
# </a>
# </li>
# <li>
# <a class="sub-nav-item festival-nav-item link-secondary" href="/en/program/piano-fest-2024">
# <h2 class="wrap">
# <span class="h4">Piano Fest 2024</span>
# <span class="preline">09.05.-12.05.2024</span>
# </h2>
# </a>
# </li>
# <li>
# <a class="sub-nav-item festival-nav-item link-secondary active" href="/en/program/summer-festival-24">
# <h2 class="wrap">
# <span class="h4">Summer Festival 2024</span>
# <span class="preline">13.08.-15.09.2024</span>
# </h2>
# </a>
# </li>
# <li>
# <a class="sub-nav-item festival-nav-item link-secondary" href="/en/forward">
# <h2 class="wrap">
# <span class="h4">Forward Festival 2024</span>
# <span class="preline">15.11.-17.11.2024</span>
# </h2>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </nav>
# </header>
# <div class="spacer"></div>
# <div class="spacer show-for-medium"></div>
# <section class="grid-container">
# <div class="filter-bar grid-x grid-margin-x align-justify align-middle">
# <div class="cell medium-shrink">
# <div class="grid-x grid-margin-x align-justify">
# <div class="cell">
# <div class="filter-overlay-container overlay-container">
# <button class="open-filter open-overlay link-secondary">
# <span class="icon"></span>
# <span class="button-text p bold link-secondary">Filter: Time period and Divisions</span>
# </button>
# <div class="filter-overlay-content overlay-content text-left">
# <div class="relative">
# <div class="grid-x grid-margin-x align-justify">
# <div class="cell auto">
# <strong class="filter-title p"><span class="icon icon-calendar-24"></span><span>Time period and Divisions</span></strong>
# <div class="festival-title clr-pri p">Summer Festival 2024 | 13.08.-15.09.2024</div>
# </div>
# <div class="cell shrink">
# <button class="close-filter close-overlay button-close" title="Schließen">
# <span class="show-for-sr">close</span>
# </button>
# </div>
# </div>
# <div class="filter-row">
# <div class="grid-x grid-margin-x">
# <div class="cell large-3 left-col">
# <strong class="caption p">Time period</strong>
# </div>
# <div class="cell auto">
# <div class="calendar-container"></div>
# </div>
# </div>
# </div>
# <div class="filter-row">
# <div class="grid-x grid-margin-x align-middle">
# <div class="cell large-3 left-col">
# <strong class="caption p">Divisions</strong>
# </div>
# <div class="cell auto">
# <ul class="sparte-list">
# <li>
# <button class="sparte-item p clr-pri active" data-slug="" href=""><span>Alle Sparten</span></button>
# </li>
# <li>
# <button class="sparte-item p clr-pri" data-slug="symphony" href="/en/program/summer-festival-24?category=symphony"><span>Symphony</span></button>
# </li>
# <li>
# <button class="sparte-item p clr-pri" data-slug="music_for_future" href="/en/program/summer-festival-24?category=music_for_future"><span>Music for Future</span></button>
# </li>
# <li>
# <button class="sparte-item p clr-pri" data-slug="contemporary" href="/en/program/summer-festival-24?category=contemporary"><span>Contemporary</span></button>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="filter-bottom">
# <button class="show-results button small-extended clr-sec" onclick="window.location.reload();">Show results</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="cell medium-shrink">
# <a class="tickets-available link-secondary" href="/en/program/summer-festival-24?tickets_available=True">
# <span class="icon"></span>
# <span class="button-text p bold">Tickets available</span>
# </a>
# </div>
# <div class="cell grow">
# <ul class="tag-list">
# </ul>
# </div>
# </div>
# <ul class="event-list">
# <li class="event-item fl-clr yellow" loading="lazy">
# <div class="event-content">
# <span class="date-item h4">Tue 13.08.</span>
# <div class="grid-x grid-margin-x">
# <div class="cell shrink show-for-large">
# <a class="event-image-link" href="/en/program/youth-symphony-orchestra-of-ukraine-oksana-lyniv/2024" tabindex="-1">
# <figure>
# <picture class="clr-sec">
# <source media="(min-width: 1280px)" srcset="/media/thumbnails/filer_public/7e/8c/7e8cc114-18d2-4b2e-a504-686db42a430b/youth_symphony_orchestra_of_ukraine_lyniv2_c_mutesouvenir_kaibienert.jpg__300x200_q85_crop_subject_location-1470%2C847_subsampling-2_upscale.jpg"/>
# <source media="(min-width: 1024px)" srcset="/media/thumbnails/filer_public/7e/8c/7e8cc114-18d2-4b2e-a504-686db42a430b/youth_symphony_orchestra_of_ukraine_lyniv2_c_mutesouvenir_kaibienert.jpg__200x133_q85_crop_subject_location-1470%2C847_subsampling-2_upscale.jpg"/>
# <img alt="Youth Symphony Orchestra of Ukraine | Oksana Lyniv" loading="lazy" src="..."/>
# </picture>
# </figure>
# </a>
# </div>
# <div class="event-text cell auto grow">
# <div class="body-small">Youth Symphony Orchestra of Ukraine</div>
# <p class="event-title h3">
# <a href="/en/program/youth-symphony-orchestra-of-ukraine-oksana-lyniv/2024">Youth Symphony Orchestra of Ukraine | Oksana Lyniv</a>
# </p>
# <div class="grid-x grid-margin-x">
# <div class="cell medium-7 xlarge-8">
# <div class="grid-x grid-margin-x">
# <div class="cell xlarge-6 body-small">
# <strong>Date and Venue</strong><br/>
#                                 Tue 13.08. | 19.30
# 								| KKL Luzern, Concert Hall
#                             </div>
# <div class="cell xlarge-6 body-small">
# <strong>Program</strong><br/>
#                                 Debussy | Elgar  | Ljatoschynskyj | Respighi
#                             </div>
# </div>
# </div>
# <div class="cell medium-5 xlarge-4 ticket-status">
# <div class="body-small bold">Summer Festival 2024</div>
# <span class="status tickets-availability">Tickets as from 19.3. | 12 pm (CET)</span>
# <div class="prices">starting at CHF 50</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="event-item fl-clr yellow" loading="lazy">
# <div class="event-content">
# <span class="date-item h4">Wed 14.08.</span>
# <div class="grid-x grid-margin-x">
# <div class="cell shrink show-for-large">
# <a class="event-image-link" href="/en/program/european-union-youth-orchestra-gianandrea-noseda-nicolas-altstaedt/2026" tabindex="-1">
# <figure>
# <picture class="clr-sec">
# <source media="(min-width: 1280px)" srcset="/media/thumbnails/filer_public/df/4f/df4f34e3-6bd0-460b-bb06-05f7f7c4ffc4/euyo_2023_sven-kristian_wolf.jpg__300x200_q85_crop_subject_location-2912%2C1764_subsampling-2_upscale.jpg"/>
# <source media="(min-width: 1024px)" srcset="/media/thumbnails/filer_public/df/4f/df4f34e3-6bd0-460b-bb06-05f7f7c4ffc4/euyo_2023_sven-kristian_wolf.jpg__200x133_q85_crop_subject_location-2912%2C1764_subsampling-2_upscale.jpg"/>
# <img alt="European Union Youth Orchestra" loading="lazy" src="..."/>
# </picture>
# </figure>
# </a>
# </div>
# <div class="event-text cell auto grow">
# <div class="body-small">European Union Youth Orchestra</div>
# <p class="event-title h3">
# <a href="/en/program/european-union-youth-orchestra-gianandrea-noseda-nicolas-altstaedt/2026">European Union Youth Orchestra | Gianandrea Noseda | Nicolas Altstaedt</a>
# </p>
# <div class="grid-x grid-margin-x">
# <div class="cell medium-7 xlarge-8">
# <div class="grid-x grid-margin-x">
# <div class="cell xlarge-6 body-small">
# <strong>Date and Venue</strong><br/>
#                                 Wed 14.08. | 19.30
# 								| KKL Luzern, Concert Hall
#                             </div>
# <div class="cell xlarge-6 body-small">
# <strong>Program</strong><br/>
#                                 Simon | Britten | Strauss
#                             </div>
# </div>
# </div>
# <div class="cell medium-5 xlarge-4 ticket-status">
# <div class="body-small bold">Summer Festival 2024</div>
# <span class="status tickets-availability">Tickets as from 19.3. | 12 pm (CET)</span>
# <div class="prices">starting at CHF 50</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="event-item fl-clr yellow" loading="lazy">
# <div class="event-content">
# <span class="date-item h4">Fri 16.08.</span>
# <div class="grid-x grid-margin-x">
# <div class="cell shrink show-for-large">
# <a class="event-image-link" href="/en/program/lucerne-festival-orchestra-riccardo-chailly/2028" tabindex="-1">
# <figure>
# <picture class="clr-sec">
# <source media="(min-width: 1280px)" srcset="/media/thumbnails/filer_public/d3/25/d325af82-6571-429e-b27a-aac0df8ac7f2/220812_lfo_1_lfo_chailly_c_priskaketterer_lucerne_festival_14_approved.jpg__300x200_q85_crop_subject_location-2205%2C1533_subsampling-2_upscale.jpg"/>
# <source media="(min-width: 1024px)" srcset="/media/thumbnails/filer_public/d3/25/d325af82-6571-429e-b27a-aac0df8ac7f2/220812_lfo_1_lfo_chailly_c_priskaketterer_lucerne_festival_14_approved.jpg__200x133_q85_crop_subject_location-2205%2C1533_subsampling-2_upscale.jpg"/>
# <img alt="Lucerne Festival Orchestra | Riccardo Chailly" loading="lazy" src="..."/>
# </picture>
# </figure>
# </a>
# </div>
# <div class="event-text cell auto grow">
# <div class="body-small">Lucerne Festival Orchestra 1: Opening</div>
# <p class="event-title h3">
# <a href="/en/program/lucerne-festival-orchestra-riccardo-chailly/2028">Lucerne Festival Orchestra | Riccardo Chailly</a>
# </p>
# <div class="grid-x grid-margin-x">
# <div class="cell medium-7 xlarge-8">
# <div class="grid-x grid-margin-x">
# <div class="cell xlarge-6 body-small">
# <strong>Date and Venue</strong><br/>
#                                 Fri 16.08. | 18.30
# 								| KKL Luzern, Concert Hall
#                             </div>
# <div class="cell xlarge-6 body-small">
# <strong>Program</strong><br/>
#                                 Mahler
#                             </div>
# </div>
# </div>
# <div class="cell medium-5 xlarge-4 ticket-status">
# <div class="body-small bold">Summer Festival 2024</div>
# <span class="status tickets-availability">Tickets as from 19.3. | 12 pm (CET)</span>
# <div class="prices">starting at CHF
a>
# </p>
# <div class="grid-x grid-margin-x">
# <div class="cell medium-7 xlarge-8">
# <div class="grid-x grid-margin-x">
# <div class="cell xlarge-6 body-small">
# <strong>Date and Venue</strong><br/>
#                                 Wed 21.08. | 17.00
# 								| KKL Luzern, Concert Hall
#                             </div>
# <div class="cell xlarge-6 body-small">
# <strong>Program</strong><br/>
#                                 Wagner
#                             </div>
# </div>
# </div>
# <div class="cell medium-5 xlarge-4 ticket-status">
# <div class="body-small bold">Summer Festival 2024</div>
# <span class="status tickets-availability">Tickets as from 19.3. | 12 pm (CET)</span>
# <div class="prices">starting at CHF 30</div>
# </div>
# </div>
# <div class="sponsor-info">This concert is made possible by Regula Gerber.</div>
# </div>
# </div>
# </div>
# </li>
# <li class="event-item fl-clr yellow" loading="lazy">
# <div class="event-content">
# <span class="date-item h4">Thu 22.08.</span>
# <div class="grid-x grid-margin-x">
# <div class="cell shrink show-for-large">
# <a class="event-image-link" href="/en/program/tjasha-gafner/2069" tabindex="-1">
# <figure>
# <picture class="clr-sec">
# <source media="(min-width: 1280px)" srcset="/media/thumbnails/filer_public/34/41/3441c59d-91d8-4817-bda8-072bb04950f4/gafner_c_patrick_martin.jpg__300x200_q85_crop_subject_location-520%2C310_subsampling-2_upscale.jpg"/>
# <source media="(min-width: 1024px)" srcset="/media/thumbnails/filer_public/34/41/3441c59d-91d8-4817-bda8-072bb04950f4/gafner_c_patrick_martin.jpg__200x133_q85_crop_subject_location-520%2C310_subsampling-2_upscale.jpg"/>
# <img alt="Tjasha Gafner" loading="lazy" src="..."/>
# </picture>
# </figure>
# </a>
# </div>
# <div class="event-text cell auto grow">
# <div class="body-small">Debut Tjasha Gafner</div>
# <p class="event-title h3">
# <a href="/en/program/tjasha-gafner/2069">Tjasha Gafner</a>
# </p>
# <div class="grid-x grid-margin-x">
# <div class="cell medium-7 xlarge-8">
# <div class="grid-x grid-margin-x">
# <div class="cell xlarge-6 body-small">
# ...
# </li>
# <li>
# <a class="link-secondary" href="/en/data-privacy">Data Protection and Privacy</a>
# </li>
# <li>
# <a class="link-secondary" href="/en/gtc">GTC</a>
# </li>
# <li>
# <a class="link-secondary" href="/en/publishing-credits">Publishing Credits</a>
# </li>
# <li>
# <a class="link-secondary" href="javascript:window.CookieManager.show()" title="Cookie settings">Cookie settings</a>
# </li>
# </ul>
# </div>
# <div class="cell xlarge-4 text-center">
# <ul class="footer-social-media social-media-list">
# <li>
# <a href="https://www.facebook.com/lucernefestival" target="_blank">
# <span class="show-for-sr">Facebook</span>
# <svg fill="none" height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
# <path d="M24 48C37.2548 48 48 37.2548 48 24C48 10.7452 37.2548 0 24 0C10.7452 0 0 10.7452 0 24C0 37.2548 10.7452 48 24 48Z" fill="black"></path>
# <path d="M26.2473 17.1107H30V13H26.2473C24.8565 13.0026 23.5235 13.5091 22.5401 14.4085C21.5566 15.308 21.0029 16.5271 21 17.7991V19.9043H18V24.025H21V35H25.4727V24.025H29.2145L29.9673 19.9043H25.4727V17.849C25.4667 17.7531 25.4824 17.6571 25.5187 17.5671C25.5551 17.477 25.6114 17.3948 25.6841 17.3255C25.7568 17.2562 25.8443 17.2013 25.9412 17.1644C26.0381 17.1274 26.1423 17.1092 26.2473 17.1107V17.1107Z" fill="white"></path>
# </svg>
# </a>
# </li>
# <li>
# <a href="https://www.twitter.com/lucernefestival" target="_blank">
# <span class="show-for-sr">Twitter</span>
# <svg fill="none" height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
# <path d="M24
.3042 17.1921 19.5731 17.1378C19.8419 17.0835 20.1208 17.1103 20.3743 17.2148C20.6279 17.3192 20.8447 17.4966 20.9973 17.7245C21.1499 17.9524 21.2314 18.2204 21.2314 18.4947C21.2314 18.86 21.087 19.2105 20.8297 19.4698C20.5724 19.7291 20.223 19.8762 19.8577 19.879V19.879ZM30.8577 30.879H28.153V25.3737C28.1226 25.0289 27.9642 24.7079 27.709 24.4741C27.4537 24.2404 27.1201 24.1107 26.774 24.1107C26.4278 24.1107 26.0942 24.2404 25.839 24.4741C25.5837 24.7079 25.4253 25.0289 25.395 25.3737V30.879H22.6476V21.2953H25.395V22.999C25.97 22.2217 26.8325 21.2953 27.8016 21.2953C28.668 21.3421 29.4806 21.7303 30.0614 22.375C30.6422 23.0196 30.9438 23.8682 30.9003 24.7348L30.8577 30.879Z" fill="white"></path>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-bottom">
# <div class="spacer"></div>
# <div class="clip-path black-container relative">
# <div class="spacer"></div>
# <div class="partners-module text-center grid-container">
# <div class="body-small">Main Sponsor Spring Festival</div>
# <div class="grid-x grid-margin-x align-center">
# <a class="partners-item cell small-6 medium-4 xlarge-2" href="https://www.lucernefestival.ch/en/danke/bucherer" id="sponsor-item-17">
# <figure>
# <div class="image">
# <img alt="" src="/media/thumbnails/filer_public/ca/8c/ca8c38a0-9569-408c-8c20-398bab432a62/web_logo_bucherer.svg__344x344.svg"/>
# </div>
# </figure>
# </a>
# </div>
# </div>
# <div class="grid-container">
# <div class="grid-x grid-margin-x align-center">
# <div class="cell small-12 xxlarge-10 shrink footer-bottom-subline">
# <div class="grid-x grid-margin-x align-center align-middle">
# <div class="cell small-12 medium-auto medium-shrink">
# <a href="https://www.musikstadt-luzern.com/" target="_blank">
# <div class="icon icon-musikstadt_luzern"></div>
# </a>
# </div>
# <a class="footer-logo-link" href="https://www.swisstopevents.ch/" target="_blank">
# <span class="icon icon-swiss-top-events"></span>
# <span class="body-small">Lucerne Festival is an official member of Swiss Top Events</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="spacer"></div>
# </div>
# </div>
# </footer>
# </div>
# <!-- <div class="dark-layer"></div> -->
# <div class="cursor">
# <svg class="cursor-icon-download" fill="none" height="16" viewbox="0 0 17 16" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M1.746 10.75v1.5a3 3 0 0 0 3 3h8.5a3 3 0 0 0 3-3v-1.5m-7.25-.5V.75m0 9.5l-3.25-3.5m3.25 3.5l3.25-3.5" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path></svg>
# </div>
# <script src="https://cdn.jsdelivr.net/npm/@fancyapps/ui@4.0/dist/fancybox.umd.js"></script>
# <script src="/static/js/build/app.min.js"></script>
# <script src="/static/js/build/events-overview.min.js"></script>
# <div data-instance="live" id="cookie-manager"></div>
# <script>
#   window.CookieManagerConfig = {
#     debug: false,
#
#     tagManager: true,
#
#     // cookie
#     cookieServices: {
#       mediaCookies: [
#         {
#           id: 'youtube',
#           title: 'Youtube',
#           link: 'https://policies.google.com/technologies/cookies?hl=en'
#         }
#       ],
#       marketingCookies: [
#         {
#           id: 'adwords',
#           title: 'Adwords',
#           link: 'https://policies.google.com/technologies/cookies?hl=en'
#         },
#         {
#           id: 'facebook',
#           title: 'Facebook',
#           link: 'https://www.facebook.com/policies/cookies/'
#         }
#       ],
#       trackingCookies: [
#         {
#           id: 'googleAnalytics',
#           title: 'Google Analytics',
#           link: 'https://policies.google.com/technologies/cookies?hl=en'
#         }
#       ],
#       requiredCookies: [
#       ],
#     },
#
#     cookieDomains: [
#       // lucernefestival
#       '.lucernefestival.ch',
#       'www.lucernefestival.ch',
#       'staging.lucernefestival.ch',
#       'django32.lucernefestival.ch'
#     ],
#
#     pagesToExclude: [
#       '/de/datenschutz',
#       '/en/data-privacy',
#       '/de/impressum',
#       'en/publishing-credits'
#     ],
#     hostsToExclude: [
#     ],
#
#     //mainDomain: '.lucernefestival.ch',
#      mainDomain: 'www.lucernefestival.ch',
#
#     // translations
#     translations: {
#       introduction: {
#         title: `Our cookies`,
#         text: `The cookies used on our site help us to continuously improve the site and provide the best possible service. You can decide for yourself which cookies you would like to accept. You can change your settings via a link in the website footer.`
#       },
#       settings: {
#         permissions: {
#           requiredCookies: {
#             title: `Required`,
#             text: `We use cookies to enable the use of our website and to guarantee that certain features work. These cookies are required and cannot be rejected.`,
#           },
#           trackingCookies: {
#             title: `Optimisation`,
#             text: `These cookies help us understand how visitors use this website. Information is collected anonymously with the aim of improving the website.`,
#           },
#           marketingCookies: {
#             title: `Marketing`,
#             text: `These cookies are set by third parties to serve personalised, more relevant advertising on websites.`,
#           },
#           mediaCookies: {
#             title: `External media`,
#             text: `We use external media to display video content or social media embeds. These services set cookies and transmit personal data outside the EU.`,
#           },
#         },
#       },
#       buttons: {
#         accept: `Agree to all`,
#         deleteCookies: `Delete cookies`,
#         saveSettings: `Save settings`,
#       },
#     },
#
#     // links come from the version 2.0
#     links: {
#       imprint: {
#         link: 'en/publishing-credits',
#         text: 'Imprint'
#       },
#       copyright: {
#         link: '/en/data-privacy' ,
#         text: 'Privacy policy'
#       }
#     },
#
#     // style come from the version 2.0
#     styles: {
#
#       modal: {
#         backgroundColor: '#fff',
#         fontSize: '18px',
#         lineHeight:'28px'
#       },
#       title: {
#         color: '#434141',
#         fontFamily: 'Mohol,Verdana,Geneva,sans-serif',
#         fontSize: '40px',
#         lineHeight: '44px'
#       },
#       buttons: {
#         acceptAll: {
#         },
#         saveSettings: {
#           backgroundColor: '#fff',
#           color: '#000'
#          // textDecoration: 'underline'
#         }
#       },
#       checkboxText: {
#         fontSize: '18px',
#         lineHeight: '28px'
#       },
#       checkboxTextOption: {
#         fontSize: '18px',
#         fontWeight: '400',
#         lineHeight: '28px'
#       },
#       link: {
#         color: '#5F5C59',
#         fontSize: '16px',
#         textDecoration: 'underline'
#       }
#     },
#
#     deleteCookiesHelper: function() {
#       console.log('inside deleteCookiesHelper')
#     },
#   }
# </script>
# <script src="/static/CookieManager/js/app.js"></script>
# </body>
# </html>

# %%
# Fetch links as List of Tag Objects
links = soup.find_all("p", attrs={'class':'event-title h3'})

# %%
links
# Out:
# [<p class="event-title h3">
#  <a href="/en/program/youth-symphony-orchestra-of-ukraine-oksana-lyniv/2024">Youth Symphony Orchestra of Ukraine | Oksana Lyniv</a>
#  </p>,
#  <p class="event-title h3">
#  <a href="/en/program
a>
#  </p>,
#  <p class="event-title h3">
#  <a href="/en/program/budapest-festival-orchestra/2022">Budapest Festival Orchestra</a>
#  </p>,
#  <p class="event-title h3">
#  <a href="/en/program/ndr-elbphilharmonie-orchester-ndr-vokalensemble-mdr-rundfunkchor-alan-gilbert/2021">NDR Elbphilharmonie Orchester | NDR Vokalensemble | MDR-Rundfunkchor | Alan Gilbert</a>
#  </p>]

# %%
link = links[0].find('a').get('href')

# %%
link
# Out:
# '/en/program/youth-symphony-orchestra-of-ukraine-oksana-lyniv/2024'

# %%
product_list = "https://www.lucernefestival.ch" + link

# %%
product_list
# Out:
# 'https://www.lucernefestival.ch/en/program/youth-symphony-orchestra-of-ukraine-oksana-lyniv/2024'

# %%
new_webpage = requests.get(product_list)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
new_soup = BeautifulSoup(new_webpage.content, "html.parser")

# %%
# Find the <div> tag with class "program-item p"
program_div = new_soup.find("div", class_="program-item p")

# Extract the time text
if program_div:
    # Extract text from the <div> tag
    time_text = program_div.get_text(strip=True)
    print("Time:", time_text)
else:
    print("Time information not found")
# Out:
# Time: 19.30

# %%
# Find the <div> tag with id "program"
program_div = new_soup.find("section", id="program")

# Extract the program names
if program_div:
    # Find all <div> tags with class "program-item p"
    program_items = program_div.find_all("div", class_="program-item p")
    
    # Extract and format the text from each program item
    program_names = []
    for item in program_items:
        strong_tag = item.find("strong")
        if strong_tag:
            composer = strong_tag.get_text(strip=True)
            additional_info_tag = item.find("strong").find_next_sibling(string=True)  
            additional_info = additional_info_tag.strip() if additional_info_tag else ""  
            composition_tag = item.find("em")
            composition = composition_tag.get_text(strip=True) if composition_tag else "" 
            program_names.append(f"{composer} {additional_info}\n{composition}")
    
    # Join program names with newline
    programs = "\n".join(program_names)
    
    print("Program Names:")
    print(programs)
else:
    print("Program section not found")
# Out:
# Program Names:
# Carlos Simon (*1986)
# Fate Now Conquers
# Benjamin Britten (1913–1976)
# The Young Person’s Guide to the Orchestra
# Richard Strauss (1864–1949)
# Don Quixote

# %%
header_tag = new_soup.find("header", class_="page-header clip-path clr-pri")

# Extract the title text
if header_tag:
    # Find the <span> tag with class "subtitle" within the <header> tag
    subtitle_tag = header_tag.find("span", class_="subtitle")
    if subtitle_tag:
        title_text = subtitle_tag.text.strip()
        print("Title:", title_text)
    else:
        print("Subtitle tag not found within the header tag")
else:
    print("Header tag not found")
# Out:
# Title: Lucerne Festival Orchestra 3

# %%
# Find the <ul> tag with class "performers-list"
performers_ul = new_soup.find("ul", class_="performers-list")

# Extract the performer names
if performers_ul:
    # Find all <strong> tags within the <ul> tag
    performer_strong_tags = performers_ul.find_all("strong")
    
    # Extract the text from each <strong> tag and join them with comma
    performer_names = [strong_tag.get_text(strip=True) for strong_tag in performer_strong_tags]
    
    # Join performer names with comma
    performers = ", ".join(performer_names)
    
    print("Performers:", performers)
else:
    print("Performers list not found")
# Out:
# Performers: Soloists of the Lucerne Festival Orchestra

# %%
# Extract the venue
venue_div = new_soup.find("div", class_="cell large-6 subtitle")
venue_text = venue_div.get_text(strip=True)
# Split the text by the separator "|"
venue = venue_text.split("|")[-1].strip()
venue
# Out:
# 'KKL Luzern, Concert Hall'

# %%
# Find the <time> tag with class="date-item h2"
date_tag = new_soup.find("time", class_="date-item h2")

# Extract the date text

date_text = date_tag.get_text().rstrip('.') 
date_text
# Out:
# 'Tue 13.08'

# %%
# Find the figure tag with class "fullscreen-image"
figure_tag = new_soup.find('figure', class_='fullscreen-image')

# Extract the img src attribute
if figure_tag:
    img_tag = figure_tag.find('img')
    if img_tag:
        image_link = img_tag['src']
        print("Image Link:", image_link)
    else:
        print("Image tag not found")
else:
    print("Figure tag not found")
# Out:
# Image Link: /media/thumbnails/filer_public/7e/8c/7e8cc114-18d2-4b2e-a504-686db42a430b/youth_symphony_orchestra_of_ukraine_lyniv2_c_mutesouvenir_kaibienert.jpg__744x744_q85_crop_subject_location-1470%2C847_subsampling-2_upscale.jpg

# %% [markdown]
# #### Final code to loop through the links to get all the mentioned informations

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_title(soup):
    header_tag = soup.find("header", class_="page-header clip-path clr-pri")
    if header_tag:
        subtitle_tag = header_tag.find("span", class_="subtitle")
        if subtitle_tag:
            return subtitle_tag.text.strip()
    return ""
    
# Function to extract Venue
def get_venue(soup):
    try:
        venue_div = soup.find("div", class_="cell large-6 subtitle")
        venue_text = venue_div.get_text(strip=True)
        venue = venue_text.split("|")[-1].strip()
    except AttributeError:
        venue = ""
    return venue
    
# Function to extract Date
def get_date(soup):
    try:
        date_tag = soup.find("time", class_="date-item h2")
        date_text = date_tag.get_text().rstrip('.')
    except AttributeError:
        date_text = ""
    return date_text   
    
def get_time(soup):
    program_div = soup.find("div", class_="program-item p")
    if program_div:
        time_text = program_div.get_text(strip=True)
    return time_text


def get_image_link(soup):
    figure_tag = soup.find('figure', class_='fullscreen-image')
    if figure_tag:
        img_tag = figure_tag.find('img')
        if img_tag:
            return "https://www.lucernefestival.ch" + img_tag['src']
    return ""

def get_artists(soup):
    performers_ul = soup.find("ul", class_="performers-list")
    artists = []
    if performers_ul:
        performer_strong_tags = performers_ul.find_all("strong")
        for strong_tag in performer_strong_tags:
            artists.append(strong_tag.get_text(strip=True))
    return artists

def get_programs(soup):
    program_div = soup.find("section", id="program")
    programs = []
    if program_div:
        program_items = program_div.find_all("div", class_="program-item p")
        for item in program_items:
            strong_tag = item.find("strong")
            if strong_tag:
                composer = strong_tag.get_text(strip=True)
                additional_info_tag = item.find("strong").find_next_sibling(string=True)
                additional_info = additional_info_tag.strip() if additional_info_tag else ""
                composition_tag = item.find("em")
                composition = composition_tag.get_text(strip=True) if composition_tag else ""
                programs.append(f"{composer} {additional_info}\n{composition}")
    return programs

if __name__ == '__main__':
    URL = 'https://www.lucernefestival.ch/en/program/summer-festival-24'
    webpage = requests.get(URL)
    soup = BeautifulSoup(webpage.content, "html.parser")
    links = soup.find_all("p", attrs={'class': 'event-title h3'})

    data = {"title": [], "venue": [], "date": [], "time": [], "artist": [], "program": [], "image_link": []}

    for link in links:
        event_link = link.find('a').get('href')
        event_url = "https://www.lucernefestival.ch" + event_link
        event_webpage = requests.get(event_url)
        event_soup = BeautifulSoup(event_webpage.content, "html.parser")

        title = get_title(event_soup)
        venue = get_venue(event_soup)
        date = get_date(event_soup)
        time = get_time(event_soup)
        image_link = get_image_link(event_soup)
        artists = get_artists(event_soup)
        programs = get_programs(event_soup)

        for artist in artists:
            for program in programs:
                data["title"].append(title)
                data["venue"].append(venue)
                data["date"].append(date)
                data["time"].append(time)
                data["artist"].append(artist)
                data["program"].append(program)
                data["image_link"].append(image_link)

    lucerne_df = pd.DataFrame(data)
    lucerne_df.to_csv("lucerne_festival_data.csv", header=True, index=False)

# %%
test_dataframe = lucerne_df.copy(deep = True)

# %%
lucerne_df
# Out:
#                                    title                     venue       date  \
# 0    Youth Symphony Orchestra of Ukraine  KKL Luzern, Concert Hall  Tue 13.08
# 1    Youth Symphony Orchestra of Ukraine  KKL Luzern, Concert Hall  Tue 13.08
# 2    Youth Symphony Orchestra of Ukraine  KKL Luzern, Concert Hall  Tue 13.08
# 3    Youth Symphony Orchestra of Ukraine  KKL Luzern, Concert Hall  Tue 13.08
# 4    Youth Symphony Orchestra of Ukraine  KKL Luzern, Concert Hall  Tue 13.08
# ..                                   ...                       ...        ...
# 281                         Gurre-Lieder  KKL Luzern, Concert Hall  Sun 15.09
# 282                         Gurre-Lieder  KKL Luzern, Concert Hall  Sun 15.09
# 283                         Gurre-Lieder  KKL Luzern, Concert Hall  Sun 15.09
# 284                         Gurre-Lieder  KKL Luzern, Concert Hall  Sun 15.09
# 285                         Gurre-Lieder  KKL Luzern, Concert Hall  Sun 15.09
#
#       time                               artist  \
# 0    19.30  Youth Symphony Orchestra of Ukraine
# 1    19.30  Youth Symphony Orchestra of Ukraine
# 2    19.30  Youth Symphony Orchestra of Ukraine
# 3    19.30  Youth Symphony Orchestra of Ukraine
# 4    19.30                         Oksana Lyniv
# ..     ...                                  ...
# 281  18.30                    Christina Nilsson
# 282  18.30                         Jamie Barton
# 283  18.30                       Michael Schade
# 284  18.30                         Michael Nagy
# 285  18.30                     Thomas Quasthoff
#
#                                                program  \
# 0    Claude Debussy (1862–1918)\nPrélude à l'après-...
# 1                           Edward Elgar (1857–1934)\n
# 2       Borys Ljatoschynskyj (1895–1968)\nSlavic Suite
# 3          Ottorino Respighi (1879–1936)\nPini di Roma
# 4    Claude Debussy (1862–1918)\nPrélude à l'après-...
# ..                                                 ...
# 281        Arnold Schoenberg (1874–1951)\nGurre-Lieder
# 282        Arnold Schoenberg (1874–1951)\nGurre-Lieder
# 283        Arnold Schoenberg (1874–1951)\nGurre-Lieder
# 284        Arnold Schoenberg (1874–1951)\nGurre-Lieder
# 285        Arnold Schoenberg (1874–1951)\nGurre-Lieder
#
#                                             image_link
# 0    https://www.lucernefestival.ch/media/thumbnail...
# 1    https://www.lucernefestival.ch/media/thumbnail...
# 2    https://www.lucernefestival.ch/media/thumbnail...
# 3    https://www.lucernefestival.ch/media/thumbnail...
# 4    https://www.lucernefestival.ch/media/thumbnail...
# ..                                                 ...
# 281  https://www.lucernefestival.ch/media/thumbnail...
# 282  https://www.lucernefestival.ch/media/thumbnail...
# 283  https://www.lucernefestival.ch/media/thumbnail...
# 284  https://www.lucernefestival.ch/media/thumbnail...
# 285  https://www.lucernefestival.ch/media/thumbnail...
#
# [286 rows x 7 columns]

# %%
# Separate dataframes for title, venue, artist, and program
title_df = lucerne_df[['title']]
venue_df = lucerne_df[['venue']]
artist_df = lucerne_df[['artist']]
program_df = lucerne_df[['program']]

# %% [markdown]
# #### Defining Schema for Postgres insertion

# %%
import psycopg2
from psycopg2 import sql
from psycopg2.extras import execute_values
import pandas as pd

# Establish a connection to the PostgreSQL database
conn = psycopg2.connect(user="postgres",
                                      password="postgres",
                                      host="localhost",
                                      port="5432",
                                      database="docker")

cursor = conn.cursor()

# Create tables
create_tables_query = """

-- Create venues table
CREATE TABLE IF NOT EXISTS venues (
    venue_id SERIAL PRIMARY KEY,
    venue_name VARCHAR(255)
);

-- Create artists table
CREATE TABLE IF NOT EXISTS artists (
    artist_id SERIAL PRIMARY KEY,
    artist_name VARCHAR(255)
);

-- Create programs table
CREATE TABLE IF NOT EXISTS programs (
    program_id SERIAL PRIMARY KEY,
    program_name VARCHAR(255)
);

-- Create programs table
CREATE TABLE IF NOT EXISTS titles (
    title_id SERIAL PRIMARY KEY,
    title_name VARCHAR(255)
);

-- Create events table
CREATE TABLE IF NOT EXISTS events (
    title_id INTEGER,
    venue_id INTEGER,
    event_date DATE,
    event_time TIME,
    artist_id INTEGER,
    program_id INTEGER,
    image_link TEXT
);

-- Add foreign key constraint for artist_id in events table
ALTER TABLE events ADD CONSTRAINT fk_artist_id FOREIGN KEY (artist_id) REFERENCES artists(artist_id);

-- Add foreign key constraint for venue_id in events table
ALTER TABLE events ADD CONSTRAINT fk_venue_id FOREIGN KEY (venue_id) REFERENCES venues(venue_id);

-- Add foreign key constraint for program_id in events table
ALTER TABLE events ADD CONSTRAINT fk_program_id FOREIGN KEY (program_id) REFERENCES programs(program_id);

-- Add foreign key constraint for program_id in events table
ALTER TABLE events ADD CONSTRAINT fk_title_id FOREIGN KEY (title_id) REFERENCES titles(title_id);

"""

# Execute the query to create tables
cursor.execute(create_tables_query)

# Commit the transaction
conn.commit()

# %%
# Iterate through the program_df dataframe to extract unique program names
unique_programs = set(program_df['program'])
unique_artist = set(artist_df['artist'])
unique_venue = set(venue_df['venue'])
unique_title = set(title_df['title'])

# Insert each unique program name into the programs table
for program_name in unique_programs:
    # Execute the SQL query to insert the program name
    cursor.execute("INSERT INTO programs (program_name) VALUES (%s) ON CONFLICT DO NOTHING", (program_name,))

for artist_name in unique_artist:
    # Execute the SQL query to insert the program name
    cursor.execute("INSERT INTO artists (artist_name) VALUES (%s) ON CONFLICT DO NOTHING", (artist_name,))

for venue_name in unique_venue:
    # Execute the SQL query to insert the program name
    cursor.execute("INSERT INTO venues (venue_name) VALUES (%s) ON CONFLICT DO NOTHING", (venue_name,))

for title_name in unique_title:
    # Execute the SQL query to insert the program name
    cursor.execute("INSERT INTO titles (title_name) VALUES (%s) ON CONFLICT DO NOTHING", (title_name,))
    
# Commit the transaction and close the cursor and connection
conn.commit()

# %%
# Define a function to get the ID for a given name from the database
def get_id(table_name, column_name1, column_name2, value):
    query = sql.SQL("SELECT {} FROM {} WHERE {} = %s").format(sql.Identifier(column_name1), sql.Identifier(table_name), sql.Identifier(column_name2))
    cursor.execute(query, (value,))
    result = cursor.fetchone()
    if result:
        return result[0]
    else:
        return None

# Iterate through each row in the DataFrame and replace the column values with their corresponding IDs
for index, row in test_dataframe.iterrows():
    title_id = get_id('titles', 'title_id', 'title_name', row['title'])
    venue_id = get_id('venues', 'venue_id', 'venue_name', row['venue'])
    artist_id = get_id('artists', 'artist_id', 'artist_name', row['artist'])
    program_id = get_id('programs', 'program_id', 'program_name', row['program'])
    
    # Replace the column values with their corresponding IDs
    test_dataframe.at[index, 'title'] = title_id
    test_dataframe.at[index, 'venue'] = venue_id
    test_dataframe.at[index, 'artist'] = artist_id
    test_dataframe.at[index, 'program'] = program_id
# Out:
# Found ID 39 for Youth Symphony Orchestra of Ukraine
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 44 for Youth Symphony Orchestra of Ukraine
# Found ID 84 for Claude Debussy (1862–1918)
# Prélude à l'après-midi d'un faune
# Found ID 39 for Youth Symphony Orchestra of Ukraine
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 44 for Youth Symphony Orchestra of Ukraine
# Found ID 27 for Edward Elgar (1857–1934)
#
# Found ID 39 for Youth Symphony Orchestra of Ukraine
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 44 for Youth Symphony Orchestra of Ukraine
# Found ID 59 for Borys Ljatoschynskyj (1895–1968)
# Slavic Suite
# Found ID 39 for Youth Symphony Orchestra of Ukraine
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 44 for Youth Symphony Orchestra of Ukraine
# Found ID 47 for Ottorino Respighi (1879–1936)
# Pini di Roma
# Found ID 39 for Youth Symphony Orchestra of Ukraine
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 8 for Oksana Lyniv
# Found ID 84 for Claude Debussy (1862–1918)
# Prélude à l'après-midi d'un faune
# Found ID 39 for Youth Symphony Orchestra of Ukraine
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 8 for Oksana Lyniv
# Found ID 27 for Edward Elgar (1857–1934)
#
# Found ID 39 for Youth Symphony Orchestra of Ukraine
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 8 for Oksana Lyniv
# Found ID 59 for Borys Ljatoschynskyj (1895–1968)
# Slavic Suite
# Found ID 39 for Youth Symphony Orchestra of Ukraine
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 8 for Oksana Lyniv
# Found ID 47 for Ottorino Respighi (1879–1936)
# Pini di Roma
# Found ID 13 for European Union Youth Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 80 for European Union Youth Orchestra
# Found ID 65 for Carlos Simon (*1986)
# Fate Now Conquers
# Found ID 13 for European Union Youth Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 80 for European Union Youth Orchestra
# Found ID 80 for Benjamin Britten (1913–1976)
# The Young Person’s Guide to the Orchestra
# Found ID 13 for European Union Youth Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 80 for European Union Youth Orchestra
# Found ID 97 for Richard Strauss (1864–1949)
# Don Quixote
# Found ID 13 for European Union Youth Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 15 for Gianandrea Noseda
# Found ID 65 for Carlos Simon (*1986)
# Fate Now Conquers
# Found ID 13 for European Union Youth Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 15 for Gianandrea Noseda
# Found ID 80 for Benjamin Britten (1913–1976)
# The Young Person’s Guide to the Orchestra
# Found ID 13 for European Union Youth Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 15 for Gianandrea Noseda
# Found ID 97 for Richard Strauss (1864–1949)
# Don Quixote
# Found ID 13 for European Union Youth Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 50 for Nicolas Altstaedt
# Found ID 65 for Carlos Simon (*1986)
# Fate Now Conquers
# Found ID 13 for European Union Youth Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 50 for Nicolas Altstaedt
# Found ID 80 for Benjamin Britten (1913–1976)
# The Young Person’s Guide to the Orchestra
# Found ID 13 for European Union Youth Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 50 for Nicolas Altstaedt
# Found ID 97 for Richard Strauss (1864–1949)
# Don Quixote
# Found ID 2 for Lucerne Festival Orchestra 1: Opening
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 79 for Lucerne Festival Orchestra
# Found ID 90 for Gustav Mahler (1860–1911)
#
# Found ID 2 for Lucerne Festival Orchestra 1: Opening
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 56 for Riccardo Chailly
# Found ID 90 for Gustav Mahler (1860–1911)
#
# Found ID 31 for Lucerne Festival Orchestra 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 79 for Lucerne Festival Orchestra
# Found ID 75 for Felix Mendelssohn (1809–1847)
# The Hebrides or Fingal’s Cave
# Found ID 31 for Lucerne Festival Orchestra 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 79 for Lucerne Festival Orchestra
# Found ID 89 for Edvard Grieg (1843–1907)
#
# Found ID 31 for Lucerne Festival Orchestra 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 79 for Lucerne Festival Orchestra
# Found ID 2 for Robert Schumann (1810–1856)
#
# Found ID 31 for Lucerne Festival Orchestra 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 41 for Klaus Mäkelä
# Found ID 75 for Felix Mendelssohn (1809–1847)
# The Hebrides or Fingal’s Cave
# Found ID 31 for Lucerne Festival Orchestra 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 41 for Klaus Mäkelä
# Found ID 89 for Edvard Grieg (1843–1907)
#
# Found ID 31 for Lucerne Festival Orchestra 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 41 for Klaus Mäkelä
# Found ID 2 for Robert Schumann (1810–1856)
#
# Found ID 31 for Lucerne Festival Orchestra 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 19 for Leif Ove Andsnes
# Found ID 75 for Felix Mendelssohn (1809–1847)
# The Hebrides or Fingal’s Cave
# Found ID 31 for Lucerne Festival Orchestra 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 19 for Leif Ove Andsnes
# Found ID 89 for Edvard Grieg (1843–1907)
#
# Found ID 31 for Lucerne Festival Orchestra 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 19 for Leif Ove Andsnes
# Found ID 2 for Robert Schumann (1810–1856)
#
# Found ID 19 for Lucerne Festival Academy 1
# Found ID 6 for KKL Luzern, Lucerne Hall
# Found ID 42 for Soloists of the Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 112 for “Anniversary Concert: 20 Years of Lucerne Festival Academy”
#
# Found ID 41 for West-Eastern Divan Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 69 for West-Eastern Divan Orchestra
# Found ID 109 for “25 Years of the West-Eastern Divan Orchestra”
#
# Found ID 41 for West-Eastern Divan Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 69 for West-Eastern Divan Orchestra
# Found ID 100 for Johannes Brahms (1833–1897)
#
# Found ID 41 for West-Eastern Divan Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 69 for West-Eastern Divan Orchestra
# Found ID 70 for Arnold Schoenberg (1874–1951)
# Pelleas und Melisande
# Found ID 41 for West-Eastern Divan Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 22 for Daniel Barenboim
# Found ID 109 for “25 Years of the West-Eastern Divan Orchestra”
#
# Found ID 41 for West-Eastern Divan Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 22 for Daniel Barenboim
# Found ID 100 for Johannes Brahms (1833–1897)
#
# Found ID 41 for West-Eastern Divan Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 22 for Daniel Barenboim
# Found ID 70 for Arnold Schoenberg (1874–1951)
# Pelleas und Melisande
# Found ID 41 for West-Eastern Divan Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 20 for Anne-Sophie Mutter
# Found ID 109 for “25 Years of the West-Eastern Divan Orchestra”
#
# Found ID 41 for West-Eastern Divan Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 20 for Anne-Sophie Mutter
# Found ID 100 for Johannes Brahms (1833–1897)
#
# Found ID 41 for West-Eastern Divan Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 20 for Anne-Sophie Mutter
# Found ID 70 for Arnold Schoenberg (1874–1951)
# Pelleas und Melisande
# Found ID 4 for Recital Mao Fujita
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 52 for Mao Fujita
# Found ID 105 for Wolfgang Amadé  Mozart (1756–1791)
#
# Found ID 4 for Recital Mao Fujita
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 52 for Mao Fujita
# Found ID 49 for Déodat de Séverac (1872–1921)
# Les Fêtes
# Found ID 4 for Recital Mao Fujita
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 52 for Mao Fujita
# Found ID 13 for Frédéric Chopin (1810–1849)
# Barcarolle
# Found ID 4 for Recital Mao Fujita
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 52 for Mao Fujita
# Found ID 58 for Sergei Prokofiev (1891–1953)
#
# Found ID 4 for Recital Mao Fujita
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 52 for Mao Fujita
# Found ID 14 for Robert Schumann (1810–1856)
# Arabeske
# Found ID 34 for Lucerne Festival Orchestra 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 79 for Lucerne Festival Orchestra
# Found ID 22 for Sergei Rachmaninoff (1873–1943)
#
# Found ID 34 for Lucerne Festival Orchestra 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 56 for Riccardo Chailly
# Found ID 22 for Sergei Rachmaninoff (1873–1943)
#
# Found ID 34 for Lucerne Festival Orchestra 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 81 for Alexander Malofeev
# Found ID 22 for Sergei Rachmaninoff (1873–1943)
#
# Found ID 3 for Die Walküre
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 77 for Dresden Festival Orchestra
# Found ID 78 for Richard Wagner (1813–1883)
# Die Walküre
# Found ID 3 for Die Walküre
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 2 for Concerto Köln
# Found ID 78 for Richard Wagner (1813–1883)
# Die Walküre
# Found ID 3 for Die Walküre
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 97 for Kent Nagano
# Found ID 78 for Richard Wagner (1813–1883)
# Die Walküre
# Found ID 3 for Die Walküre
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 49 for Simon Bailey
# Found ID 78 for Richard Wagner (1813–1883)
# Die Walküre
# Found ID 3 for Die Walküre
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 54 for Maximilian Schmitt
# Found ID 78 for Richard Wagner (1813–1883)
# Die Walküre
# Found ID 3 for Die Walküre
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 23 for Sarah Wegener
# Found ID 78 for Richard Wagner (1813–1883)
# Die Walküre
# Found ID 3 for Die Walküre
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 58 for Åsa Jäger
# Found ID 78 for Richard Wagner (1813–1883)
# Die Walküre
# Found ID 3 for Die Walküre
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 99 for Dimitry Ivashchenko
# Found ID 78 for Richard Wagner (1813–1883)
# Die Walküre
# Found ID 29 for Debut Tjasha Gafner
# Found ID 3 for Lukaskirche
# Found ID 57 for Tjasha Gafner
# Found ID 102 for Haydn ,
#
# Found ID 16 for Lucerne Symphony Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 83 for Lucerne Symphony Orchestra
# Found ID 108 for Ludwig van Beethoven (1770–1827)
#
# Found ID 16 for Lucerne Symphony Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 83 for Lucerne Symphony Orchestra
# Found ID 48 for Franz Schubert (1797–1828)
# “Great”
# Found ID 16 for Lucerne Symphony Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 103 for Michael Sanderling
# Found ID 108 for Ludwig van Beethoven (1770–1827)
#
# Found ID 16 for Lucerne Symphony Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 103 for Michael Sanderling
# Found ID 48 for Franz Schubert (1797–1828)
# “Great”
# Found ID 16 for Lucerne Symphony Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 94 for Francesco Piemontesi
# Found ID 108 for Ludwig van Beethoven (1770–1827)
#
# Found ID 16 for Lucerne Symphony Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 94 for Francesco Piemontesi
# Found ID 48 for Franz Schubert (1797–1828)
# “Great”
# Found ID 11 for Czech Philharmonic
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 4 for Czech Philharmonic
# Found ID 106 for Antonín Dvořák (1841–1904)
#
# Found ID 11 for Czech Philharmonic
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 75 for Jakub Hrůša
# Found ID 106 for Antonín Dvořák (1841–1904)
#
# Found ID 11 for Czech Philharmonic
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 98 for Sheku Kanneh-Mason
# Found ID 106 for Antonín Dvořák (1841–1904)
#
# Found ID 37 for Lucerne Festival Academy 2
# Found ID 6 for KKL Luzern, Lucerne Hall
# Found ID 16 for Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 101 for Arnold Schoenberg (1874–1951)
#
# Found ID 37 for Lucerne Festival Academy 2
# Found ID 6 for KKL Luzern, Lucerne Hall
# Found ID 16 for Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 81 for Lisa Streich (*1985)
# ISJHÄRTA
# Found ID 37 for Lucerne Festival Academy 2
# Found ID 6 for KKL Luzern, Lucerne Hall
# Found ID 16 for Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 21 for Wolfgang Rihm (*1952)
# IN-SCHRIFT
# Found ID 37 for Lucerne Festival Academy 2
# Found ID 6 for KKL Luzern, Lucerne Hall
# Found ID 16 for Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 43 for Pierre Boulez (1925–2016)
# Rituel in memoriam Bruno Maderna
# Found ID 37 for Lucerne Festival Academy 2
# Found ID 6 for KKL Luzern, Lucerne Hall
# Found ID 47 for Ruth Reinhardt
# Found ID 101 for Arnold Schoenberg (1874–1951)
#
# Found ID 37 for Lucerne Festival Academy 2
# Found ID 6 for KKL Luzern, Lucerne Hall
# Found ID 47 for Ruth Reinhardt
# Found ID 81 for Lisa Streich (*1985)
# ISJHÄRTA
# Found ID 37 for Lucerne Festival Academy 2
# Found ID 6 for KKL Luzern, Lucerne Hall
# Found ID 47 for Ruth Reinhardt
# Found ID 21 for Wolfgang Rihm (*1952)
# IN-SCHRIFT
# Found ID 37 for Lucerne Festival Academy 2
# Found ID 6 for KKL Luzern, Lucerne Hall
# Found ID 47 for Ruth Reinhardt
# Found ID 43 for Pierre Boulez (1925–2016)
# Rituel in memoriam Bruno Maderna
# Found ID 5 for Lucerne Festival Orchestra 5
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 79 for Lucerne Festival Orchestra
# Found ID 17 for Clara Schumann (1819–1896)
#
# Found ID 5 for Lucerne Festival Orchestra 5
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 79 for Lucerne Festival Orchestra
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 5 for Lucerne Festival Orchestra 5
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 95 for Yannick Nézet-Séguin
# Found ID 17 for Clara Schumann (1819–1896)
#
# Found ID 5 for Lucerne Festival Orchestra 5
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 95 for Yannick Nézet-Séguin
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 5 for Lucerne Festival Orchestra 5
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 24 for Beatrice Rana
# Found ID 17 for Clara Schumann (1819–1896)
#
# Found ID 5 for Lucerne Festival Orchestra 5
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 24 for Beatrice Rana
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 15 for Sheku Kanneh-Mason & Plínio Fernandes
# Found ID 5 for Luzerner Theater, Theatersaal
# Found ID 98 for Sheku Kanneh-Mason
# Found ID 77 for Heitor Villa-Lobos (1887–1959)
# Aria (Cantilena)
# Found ID 15 for Sheku Kanneh-Mason & Plínio Fernandes
# Found ID 5 for Luzerner Theater, Theatersaal
# Found ID 98 for Sheku Kanneh-Mason
# Found ID 18 for Radamés Gnattali (1906–1988)
#
# Found ID 15 for Sheku Kanneh-Mason & Plínio Fernandes
# Found ID 5 for Luzerner Theater, Theatersaal
# Found ID 98 for Sheku Kanneh-Mason
# Found ID 7 for Leo Brouwer (*1939)
# The Magic Space
# Found ID 15 for Sheku Kanneh-Mason & Plínio Fernandes
# Found ID 5 for Luzerner Theater, Theatersaal
# Found ID 98 for Sheku Kanneh-Mason
# Found ID 39 for Rafael Marino Arcaro (*1990)
# Élégie à une mémoire oubliée
# Found ID 15 for Sheku Kanneh-Mason & Plínio Fernandes
# Found ID 5 for Luzerner Theater, Theatersaal
# Found ID 98 for Sheku Kanneh-Mason
# Found ID 30 for Astor Piazzolla (1921–1992)
# Café 1930
# Found ID 15 for Sheku Kanneh-Mason & Plínio Fernandes
# Found ID 5 for Luzerner Theater, Theatersaal
# Found ID
# Found ID 8 for Debut Annemarie Federle
# Found ID 3 for Lukaskirche
# Found ID 6 for Junyan Chen
# Found ID 9 for Volker David Kirchner (1942–2020)
# Tre poemi
# Found ID 8 for Debut Annemarie Federle
# Found ID 3 for Lukaskirche
# Found ID 6 for Junyan Chen
# Found ID 23 for Jane Vignery (1913–1974)
#
# Found ID 8 for Debut Annemarie Federle
# Found ID 3 for Lukaskirche
# Found ID 6 for Junyan Chen
# Found ID 87 for Benjamin Britten (1913–1976)
# Epilogue
# Found ID 28 for Berliner Philharmoniker 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 30 for Berliner Philharmoniker
# Found ID 19 for Bedřich Smetana (1824–1884)
# Má vlast
# Found ID 28 for Berliner Philharmoniker 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 5 for Kirill Petrenko
# Found ID 19 for Bedřich Smetana (1824–1884)
# Má vlast
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 7 for Royal Concertgebouw Orchestra
# Found ID 85 for Carl Maria von Weber (1786–1826)
# Der Freischütz
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 7 for Royal Concertgebouw Orchestra
# Found ID 108 for Ludwig van Beethoven (1770–1827)
#
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 7 for Royal Concertgebouw Orchestra
# Found ID 46 for Gabriel Fauré (1845–1924)
# Pelléas et Mélisande.
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 7 for Royal Concertgebouw Orchestra
# Found ID 12 for Maurice Ravel (1875–1937)
# Daphnis et Chloé
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 37 for Myung-Whun Chung
# Found ID 85 for Carl Maria von Weber (1786–1826)
# Der Freischütz
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 37 for Myung-Whun Chung
# Found ID 108 for Ludwig van Beethoven (1770–1827)
#
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 37 for Myung-Whun Chung
# Found ID 46 for Gabriel Fauré (1845–1924)
# Pelléas et Mélisande.
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 37 for Myung-Whun Chung
# Found ID 12 for Maurice Ravel (1875–1937)
# Daphnis et Chloé
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 18 for Sir András Schiff
# Found ID 85 for Carl Maria von Weber (1786–1826)
# Der Freischütz
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 18 for Sir András Schiff
# Found ID 108 for Ludwig van Beethoven (1770–1827)
#
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 18 for Sir András Schiff
# Found ID 46 for Gabriel Fauré (1845–1924)
# Pelléas et Mélisande.
# Found ID 17 for Royal Concertgebouw Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 18 for Sir András Schiff
# Found ID 12 for Maurice Ravel (1875–1937)
# Daphnis et Chloé
# Found ID 33 for Recital Sheku Kanneh-Mason
# Found ID 4 for Lukaskirche, Kirchensaal
# Found ID 98 for Sheku Kanneh-Mason
# Found ID 53 for Johann Sebastian Bach to
#
# Found ID 33 for Recital Sheku Kanneh-Mason
# Found ID 4 for Lukaskirche, Kirchensaal
# Found ID 96 for Harry Baker
# Found ID 53 for Johann Sebastian Bach to
#
# Found ID 30 for Lucerne Festival Academy 3
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 16 for Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 20 for Beat Furrer (*1954)
#
# Found ID 30 for Lucerne Festival Academy 3
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 16 for Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 5 for Lisa Streich (*1985)
#
# Found ID 30 for Lucerne Festival Academy 3
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 16 for Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 31 for Morton Feldman (1926–1987)
# Coptic Light
# Found ID 30 for Lucerne Festival Academy 3
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 91 for Beat Furrer
# Found ID 20 for Beat Furrer (*1954)
#
# Found ID 30 for Lucerne Festival Academy 3
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 91 for Beat Furrer
# Found ID 5 for Lisa Streich (*1985)
#
# Found ID 30 for Lucerne Festival Academy 3
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 91 for Beat Furrer
# Found ID 31 for Morton Feldman (1926–1987)
# Coptic Light
# Found ID 30 for Lucerne Festival Academy 3
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 21 for Simon Höfele
# Found ID 20 for Beat Furrer (*1954)
#
# Found ID 30 for Lucerne Festival Academy 3
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 21 for Simon Höfele
# Found ID 5 for Lisa Streich (*1985)
#
# Found ID 30 for Lucerne Festival Academy 3
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 21 for Simon Höfele
# Found ID 31 for Morton Feldman (1926–1987)
# Coptic Light
# Found ID 22 for Recital Anna Vinnitskaya
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 85 for Anna Vinnitskaya
# Found ID 6 for Felix Mendelssohn (1809–1847)
# Song without Word
# Found ID 22 for Recital Anna Vinnitskaya
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 85 for Anna Vinnitskaya
# Found ID 25 for Jörg Widmann (*1973)
# Circus Dances
# Found ID 22 for Recital Anna Vinnitskaya
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 85 for Anna Vinnitskaya
# Found ID 61 for Robert Schumann (1810–1856)
# Carnaval.
# Found ID 35 for Klangforum Wien
# Found ID 5 for Luzerner Theater, Theatersaal
# Found ID 40 for Klangforum Wien
# Found ID 103 for Beat Furrer (*1954)
# Begehren
# Found ID 35 for Klangforum Wien
# Found ID 5 for Luzerner Theater, Theatersaal
# Found ID 33 for Cantando Admont
# Found ID 103 for Beat Furrer (*1954)
# Begehren
# Found ID 35 for Klangforum Wien
# Found ID 5 for Luzerner Theater, Theatersaal
# Found ID 91 for Beat Furrer
# Found ID 103 for Beat Furrer (*1954)
# Begehren
# Found ID 24 for The Cleveland Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 89 for The Cleveland Orchestra
# Found ID 2 for Robert Schumann (1810–1856)
#
# Found ID 24 for The Cleveland Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 89 for The Cleveland Orchestra
# Found ID 51 for Pyotr Ilyich  Tchaikovsky (1840–1893)
#
# Found ID 24 for The Cleveland Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 68 for Franz Welser-Möst
# Found ID 2 for Robert Schumann (1810–1856)
#
# Found ID 24 for The Cleveland Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 68 for Franz Welser-Möst
# Found ID 51 for Pyotr Ilyich  Tchaikovsky (1840–1893)
#
# Found ID 24 for The Cleveland Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 86 for Víkingur Ólafsson
# Found ID 2 for Robert Schumann (1810–1856)
#
# Found ID 24 for The Cleveland Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 86 for Víkingur Ólafsson
# Found ID 51 for Pyotr Ilyich  Tchaikovsky (1840–1893)
#
# Found ID 1 for Bavarian Radio Symphony Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 1 for Bavarian Radio Symphony Orchestra
# Found ID 90 for Gustav Mahler (1860–1911)
#
# Found ID 1 for Bavarian Radio Symphony Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 74 for Sir Simon Rattle
# Found ID 90 for Gustav Mahler (1860–1911)
#
# Found ID 12 for Debut Theo Plath
# Found ID 3 for Lukaskirche
# Found ID 10 for Theo Plath
# Found ID 71 for Pancho Vladiguerov (1899–1978)
# Caprice
# Found ID 12 for Debut Theo Plath
# Found ID 3 for Lukaskirche
# Found ID 10 for Theo Plath
# Found ID 35 for Claude Debussy (1862–1918)
#
# Found ID 12 for Debut Theo Plath
# Found ID 3 for Lukaskirche
# Found ID 10 for Theo Plath
# Found ID 4 for Heinz Holliger (*1939)
#
# Found ID 12 for Debut Theo Plath
# Found ID 3 for Lukaskirche
# Found ID 10 for Theo Plath
# Found ID 27 for Edward Elgar (1857–1934)
#
# Found ID 12 for Debut Theo Plath
# Found ID 3 for Lukaskirche
# Found ID 10 for Theo Plath
# Found ID 79 for Daniel Schnyder (*1961)
#
# Found ID 12 for Debut Theo Plath
# Found ID 3 for Lukaskirche
# Found ID 34 for Aris Alexander Blettenberg
# Found ID 71 for Pancho Vladiguerov (1899–1978)
# Caprice
# Found ID 12 for Debut Theo Plath
# Found ID 3 for Lukaskirche
# Found ID 34 for Aris Alexander Blettenberg
# Found ID 35 for Claude Debussy (1862–1918)
#
# Found ID 12 for Debut Theo Plath
# Found ID 3 for Lukaskirche
# Found ID 34 for Aris Alexander Blettenberg
# Found ID 4 for Heinz Holliger (*1939)
#
# Found ID 12 for Debut Theo Plath
# Found ID 3 for Lukaskirche
# Found ID 34 for Aris Alexander Blettenberg
# Found ID 27 for Edward Elgar (1857–1934)
#
# Found ID 12 for Debut Theo Plath
# Found ID 3 for Lukaskirche
# Found ID 34 for Aris Alexander Blettenberg
# Found ID 79 for Daniel Schnyder (*1961)
#
# Found ID 18 for Chineke! Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 9 for Chineke! Orchestra
# Found ID 52 for Samuel Coleridge-Taylor (1875–1912)
#
# Found ID 18 for Chineke! Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 9 for Chineke! Orchestra
# Found ID 88 for Wynton Marsalis (*1961)
#
# Found ID 18 for Chineke! Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 9 for Chineke! Orchestra
# Found ID 94 for Florence Price (1887–1953)
#
# Found ID 18 for Chineke! Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 53 for Leslie Suganandarajah
# Found ID 52 for Samuel Coleridge-Taylor (1875–1912)
#
# Found ID 18 for Chineke! Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 53 for Leslie Suganandarajah
# Found ID 88 for Wynton Marsalis (*1961)
#
# Found ID 18 for Chineke! Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 53 for Leslie Suganandarajah
# Found ID 94 for Florence Price (1887–1953)
#
# Found ID 18 for Chineke! Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 55 for Kelly Hall-Tompkins
# Found ID 52 for Samuel Coleridge-Taylor (1875–1912)
#
# Found ID 18 for Chineke! Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 55 for Kelly Hall-Tompkins
# Found ID 88 for Wynton Marsalis (*1961)
#
# Found ID 18 for Chineke! Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 55 for Kelly Hall-Tompkins
# Found ID 94 for Florence Price (1887–1953)
#
# Found ID 25 for Leipzig Gewandhaus Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 90 for Leipzig Gewandhaus Orchestra
# Found ID 105 for Wolfgang Amadé  Mozart (1756–1791)
#
# Found ID 25 for Leipzig Gewandhaus Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 90 for Leipzig Gewandhaus Orchestra
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 25 for Leipzig Gewandhaus Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 17 for Andris Nelsons
# Found ID 105 for Wolfgang Amadé  Mozart (1756–1791)
#
# Found ID 25 for Leipzig Gewandhaus Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 17 for Andris Nelsons
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 25 for Leipzig Gewandhaus Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 67 for Daniil Trifonov
# Found ID 105 for Wolfgang Amadé  Mozart (1756–1791)
#
# Found ID 25 for Leipzig Gewandhaus Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 67 for Daniil Trifonov
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 47 for Debut Isata Kanneh-Mason
# Found ID 3 for Lukaskirche
# Found ID 26 for Isata Kanneh-Mason
# Found ID 110 for Joseph Haydn (1732–1809)
#
# Found ID 47 for Debut Isata Kanneh-Mason
# Found ID 3 for Lukaskirche
# Found ID 26 for Isata Kanneh-Mason
# Found ID 17 for Clara Schumann (1819–1896)
#
# Found ID 47 for Debut Isata Kanneh-Mason
# Found ID 3 for Lukaskirche
# Found ID 26 for Isata Kanneh-Mason
# Found ID 55 for Felix Mendelssohn (1809–1847)
# A Midsummer Night’s Dream
# Found ID 47 for Debut Isata Kanneh-Mason
# Found ID 3 for Lukaskirche
# Found ID 26 for Isata Kanneh-Mason
# Found ID 72 for Carl Nielsen (1865–1931)
#
# Found ID 47 for Debut Isata Kanneh-Mason
# Found ID 3 for Lukaskirche
# Found ID 26 for Isata Kanneh-Mason
# Found ID 11 for Sofia Gubaidulina (*1931)
# Chaconne
# Found ID 14 for Orchestre de Paris
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 60 for Orchestre de Paris
# Found ID 51 for Pyotr Ilyich  Tchaikovsky (1840–1893)
#
# Found ID 14 for Orchestre de Paris
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 60 for Orchestre de Paris
# Found ID 28 for Hector Berlioz (1803–1869)
# Symphonie fantastique
# Found ID 14 for Orchestre de Paris
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 41 for Klaus Mäkelä
# Found ID 51 for Pyotr Ilyich  Tchaikovsky (1840–1893)
#
# Found ID 14 for Orchestre de Paris
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 41 for Klaus Mäkelä
# Found ID 28 for Hector Berlioz (1803–1869)
# Symphonie fantastique
# Found ID 14 for Orchestre de Paris
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 3 for Lisa Batiashvili
# Found ID 51 for Pyotr Ilyich  Tchaikovsky (1840–1893)
#
# Found ID 14 for Orchestre de Paris
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 3 for Lisa Batiashvili
# Found ID 28 for Hector Berlioz (1803–1869)
# Symphonie fantastique
# Found ID 7 for Vienna Philharmonic 1
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 84 for Vienna Philharmonic
# Found ID 29 for Felix Mendelssohn (1809–1847)
# Scottish
# Found ID 7 for Vienna Philharmonic 1
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 84 for Vienna Philharmonic
# Found ID 62 for Richard Strauss (1864–1949)
# Ein Heldenleben
# Found ID 7 for Vienna Philharmonic 1
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 66 for Christian Thielemann
# Found ID 29 for Felix Mendelssohn (1809–1847)
# Scottish
# Found ID 7 for Vienna Philharmonic 1
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 66 for Christian Thielemann
# Found ID 62 for Richard Strauss (1864–1949)
# Ein Heldenleben
# Found ID 23 for Portrait Beat Furrer & Lisa Streich
# Found ID 2 for Hochschule Luzern – Music, Salquin Concert Hall
# Found ID 13 for Ensemble Helix, Studio for Contemporary Music at the Hochschule Luzern – Musik
# Found ID 36 for Beat Furrer (*1954)
# ... cold and calm and moving
# Found ID 23 for Portrait Beat Furrer & Lisa Streich
# Found ID 2 for Hochschule Luzern – Music, Salquin Concert Hall
# Found ID 13 for Ensemble Helix, Studio for Contemporary Music at the Hochschule Luzern – Musik
# Found ID 91 for Lisa Streich (*1985)
# FRANCESCA
# Found ID 23 for Portrait Beat Furrer & Lisa Streich
# Found ID 2 for Hochschule Luzern – Music, Salquin Concert Hall
# Found ID 91 for Beat Furrer
# Found ID 36 for Beat Furrer (*1954)
# ... cold and calm and moving
# Found ID 23 for Portrait Beat Furrer & Lisa Streich
# Found ID 2 for Hochschule Luzern – Music, Salquin Concert Hall
# Found ID 91 for Beat Furrer
# Found ID 91 for Lisa Streich (*1985)
# FRANCESCA
# Found ID 20 for Lucerne Festival Academy 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 16 for Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 8 for George Benjamin (*1960)
#
# Found ID 20 for Lucerne Festival Academy 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 16 for Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 69 for Andrew Norman (*1979)
#
# Found ID 20 for Lucerne Festival Academy 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 16 for Lucerne Festival Contemporary Orchestra (LFCO)
# Found ID 99 for Hans Abrahamsen (*1952)
# Vers le Silence
# Found ID 20 for Lucerne Festival Academy 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 65 for Sir George Benjamin
# Found ID 8 for George Benjamin (*1960)
#
# Found ID 20 for Lucerne Festival Academy 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 65 for Sir George Benjamin
# Found ID 69 for Andrew Norman (*1979)
#
# Found ID 20 for Lucerne Festival Academy 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 65 for Sir George Benjamin
# Found ID 99 for Hans Abrahamsen (*1952)
# Vers le Silence
# Found ID 20 for Lucerne Festival Academy 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 87 for Jörgen van Rijen
# Found ID 8 for George Benjamin (*1960)
#
# Found ID 20 for Lucerne Festival Academy 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 87 for Jörgen van Rijen
# Found ID 69 for Andrew Norman (*1979)
#
# Found ID 20 for Lucerne Festival Academy 4
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 87 for Jörgen van Rijen
# Found ID 99 for Hans Abrahamsen (*1952)
# Vers le Silence
# Found ID 26 for Vienna Philharmonic 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 84 for Vienna Philharmonic
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 26 for Vienna Philharmonic 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 66 for Christian Thielemann
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 26 for Vienna Philharmonic 2
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 31 for Julia Hagen
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 45 for Lea Desandre & Jupiter Ensemble
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 39 for Jupiter Ensemble
# Found ID 57 for Handel ,
#
# Found ID 45 for Lea Desandre & Jupiter Ensemble
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 35 for Thomas Dunford
# Found ID 57 for Handel ,
#
# Found ID 45 for Lea Desandre & Jupiter Ensemble
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 63 for Lea Desandre
# Found ID 57 for Handel ,
#
# Found ID 40 for Staatskapelle Berlin
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 45 for Staatskapelle Berlin
# Found ID 1 for Gustav Mahler (1860–1911)
# Blumine
# Found ID 40 for Staatskapelle Berlin
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 28 for Susanna Mälkki
# Found ID 1 for Gustav Mahler (1860–1911)
# Blumine
# Found ID 40 for Staatskapelle Berlin
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 76 for Wiebke Lehmkuhl
# Found ID 1 for Gustav Mahler (1860–1911)
# Blumine
# Found ID 40 for Staatskapelle Berlin
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 62 for Eric Cutler
# Found ID 1 for Gustav Mahler (1860–1911)
# Blumine
# Found ID 9 for Mahler Chamber Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 78 for Mahler Chamber Orchestra
# Found ID 40 for Gustav Mahler (1860–1911)
# Seven Early Songs
# Found ID 9 for Mahler Chamber Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 78 for Mahler Chamber Orchestra
# Found ID 60 for Antonín Dvořák (1841–1904)
# From the New World
# Found ID 9 for Mahler Chamber Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 64 for Antonello Manacorda
# Found ID 40 for Gustav Mahler (1860–1911)
# Seven Early Songs
# Found ID 9 for Mahler Chamber Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 64 for Antonello Manacorda
# Found ID 60 for Antonín Dvořák (1841–1904)
# From the New World
# Found ID 9 for Mahler Chamber Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 36 for Anna Prohaska
# Found ID 40 for Gustav Mahler (1860–1911)
# Seven Early Songs
# Found ID 9 for Mahler Chamber Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 36 for Anna Prohaska
# Found ID 60 for Antonín Dvořák (1841–1904)
# From the New World
# Found ID 10 for Debut Adelphi Quartet
# Found ID 3 for Lukaskirche
# Found ID 88 for Adelphi Quartet
# Found ID 110 for Joseph Haydn (1732–1809)
#
# Found ID 10 for Debut Adelphi Quartet
# Found ID 3 for Lukaskirche
# Found ID 88 for Adelphi Quartet
# Found ID 98 for Orlando di Lasso (1532–1594)
# Je l‘aime bien
# Found ID 10 for Debut Adelphi Quartet
# Found ID 3 for Lukaskirche
# Found ID 88 for Adelphi Quartet
# Found ID 66 for Madli Marje Gildemann (*1994)
#
# Found ID 10 for Debut Adelphi Quartet
# Found ID 3 for Lukaskirche
# Found ID 88 for Adelphi Quartet
# Found ID 32 for Orlando di Lasso (1532–1594)
#
# Found ID 10 for Debut Adelphi Quartet
# Found ID 3 for Lukaskirche
# Found ID 88 for Adelphi Quartet
# Found ID 104 for Tom Coult (*1988)
#
# Found ID 10 for Debut Adelphi Quartet
# Found ID 3 for Lukaskirche
# Found ID 88 for Adelphi Quartet
# Found ID 98 for Orlando di Lasso (1532–1594)
# Je l‘aime bien
# Found ID 10 for Debut Adelphi Quartet
# Found ID 3 for Lukaskirche
# Found ID 88 for Adelphi Quartet
# Found ID 16 for Benjamin Britten (1913–1976)
#
# Found ID 36 for Recital Rudolf Buchbinder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 25 for Rudolf Buchbinder
# Found ID 68 for Wolfgang Amadé  Mozart (1756–1791)
# Ah, vous dirai-je Maman
# Found ID 36 for Recital Rudolf Buchbinder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 25 for Rudolf Buchbinder
# Found ID 26 for Ludwig van Beethoven (1770–1827)
# Waldstein
# Found ID 36 for Recital Rudolf Buchbinder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 25 for Rudolf Buchbinder
# Found ID 34 for Frédéric Chopin (1810–1849)
#
# Found ID 21 for Tonhalle-Orchester Zürich
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 72 for Zurich Tonhalle Orchestra
# Found ID 10 for Dmitri Shostakovich (1906–1975)
#
# Found ID 21 for Tonhalle-Orchester Zürich
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 72 for Zurich Tonhalle Orchestra
# Found ID 90 for Gustav Mahler (1860–1911)
#
# Found ID 21 for Tonhalle-Orchester Zürich
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 101 for Paavo Järvi
# Found ID 10 for Dmitri Shostakovich (1906–1975)
#
# Found ID 21 for Tonhalle-Orchester Zürich
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 101 for Paavo Järvi
# Found ID 90 for Gustav Mahler (1860–1911)
#
# Found ID 21 for Tonhalle-Orchester Zürich
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 98 for Sheku Kanneh-Mason
# Found ID 10 for Dmitri Shostakovich (1906–1975)
#
# Found ID 21 for Tonhalle-Orchester Zürich
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 98 for Sheku Kanneh-Mason
# Found ID 90 for Gustav Mahler (1860–1911)
#
# Found ID 6 for Debut Mélodie Zhao
# Found ID 3 for Lukaskirche
# Found ID 92 for Mélodie Zhao
# Found ID 105 for Wolfgang Amadé  Mozart (1756–1791)
#
# Found ID 6 for Debut Mélodie Zhao
# Found ID 3 for Lukaskirche
# Found ID 92 for Mélodie Zhao
# Found ID 111 for Franz Liszt (1811–1886)
#
# Found ID 6 for Debut Mélodie Zhao
# Found ID 3 for Lukaskirche
# Found ID 92 for Mélodie Zhao
# Found ID 83 for Mélodie Zhao (*1994)
# Shades Of Paganini
# Found ID 6 for Debut Mélodie Zhao
# Found ID 3 for Lukaskirche
# Found ID 92 for Mélodie Zhao
# Found ID 38 for George Gershwin (1898–1937)
# Rhapsody in Blue
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 14 for Munich Philharmonic
# Found ID 92 for Unsuk Chin (*1961)
# subito con forza
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 14 for Munich Philharmonic
# Found ID 95 for Henri Dutilleux (1916–2013)
# L’arbre des songes.
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 14 for Munich Philharmonic
# Found ID 73 for Michael Seltenreich (*1988)
#
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 14 for Munich Philharmonic
# Found ID 76 for Paul Ben-Haim (1897–1984)
#
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 48 for Lahav Shani
# Found ID 92 for Unsuk Chin (*1961)
# subito con forza
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 48 for Lahav Shani
# Found ID 95 for Henri Dutilleux (1916–2013)
# L’arbre des songes.
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 48 for Lahav Shani
# Found ID 73 for Michael Seltenreich (*1988)
#
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 48 for Lahav Shani
# Found ID 76 for Paul Ben-Haim (1897–1984)
#
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 93 for Renaud Capuçon
# Found ID 92 for Unsuk Chin (*1961)
# subito con forza
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 93 for Renaud Capuçon
# Found ID 95 for Henri Dutilleux (1916–2013)
# L’arbre des songes.
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 93 for Renaud Capuçon
# Found ID 73 for Michael Seltenreich (*1988)
#
# Found ID 32 for "räsonanz" – Donor Concert
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 93 for Renaud Capuçon
# Found ID 76 for Paul Ben-Haim (1897–1984)
#
# Found ID 27 for Munich Philharmonic
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 14 for Munich Philharmonic
# Found ID 107 for Johann Sebastian Bach (1685–1750)
#
# Found ID 27 for Munich Philharmonic
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 14 for Munich Philharmonic
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 27 for Munich Philharmonic
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 48 for Lahav Shani
# Found ID 107 for Johann Sebastian Bach (1685–1750)
#
# Found ID 27 for Munich Philharmonic
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 48 for Lahav Shani
# Found ID 3 for Anton Bruckner (1824–1896)
#
# Found ID 44 for Budapest Festival Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 70 for Budapest Festival Orchestra
# Found ID 96 for Sergei Prokofiev (1891–1953)
# Overture on Hebrew Themes
# Found ID 44 for Budapest Festival Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 70 for Budapest Festival Orchestra
# Found ID 82 for Béla Bartók (1881–1945)
#
# Found ID 44 for Budapest Festival Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 70 for Budapest Festival Orchestra
# Found ID 106 for Antonín Dvořák (1841–1904)
#
# Found ID 44 for Budapest Festival Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 82 for Iván Fischer
# Found ID 96 for Sergei Prokofiev (1891–1953)
# Overture on Hebrew Themes
# Found ID 44 for Budapest Festival Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 82 for Iván Fischer
# Found ID 82 for Béla Bartók (1881–1945)
#
# Found ID 44 for Budapest Festival Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 82 for Iván Fischer
# Found ID 106 for Antonín Dvořák (1841–1904)
#
# Found ID 44 for Budapest Festival Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 43 for Patricia Kopatchinskaja
# Found ID 96 for Sergei Prokofiev (1891–1953)
# Overture on Hebrew Themes
# Found ID 44 for Budapest Festival Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 43 for Patricia Kopatchinskaja
# Found ID 82 for Béla Bartók (1881–1945)
#
# Found ID 44 for Budapest Festival Orchestra
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 43 for Patricia Kopatchinskaja
# Found ID 106 for Antonín Dvořák (1841–1904)
#
# Found ID 42 for Gurre-Lieder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 100 for NDR Elbphilharmonie Orchester
# Found ID 67 for Arnold Schoenberg (1874–1951)
# Gurre-Lieder
# Found ID 42 for Gurre-Lieder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 11 for NDR Vokalensemble
# Found ID 67 for Arnold Schoenberg (1874–1951)
# Gurre-Lieder
# Found ID 42 for Gurre-Lieder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 27 for MDR-Rundfunkchor
# Found ID 67 for Arnold Schoenberg (1874–1951)
# Gurre-Lieder
# Found ID 42 for Gurre-Lieder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 32 for Alan Gilbert
# Found ID 67 for Arnold Schoenberg (1874–1951)
# Gurre-Lieder
# Found ID 42 for Gurre-Lieder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 59 for Stuart Skelton
# Found ID 67 for Arnold Schoenberg (1874–1951)
# Gurre-Lieder
# Found ID 42 for Gurre-Lieder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 51 for Christina Nilsson
# Found ID 67 for Arnold Schoenberg (1874–1951)
# Gurre-Lieder
# Found ID 42 for Gurre-Lieder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 61 for Jamie Barton
# Found ID 67 for Arnold Schoenberg (1874–1951)
# Gurre-Lieder
# Found ID 42 for Gurre-Lieder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 71 for Michael Schade
# Found ID 67 for Arnold Schoenberg (1874–1951)
# Gurre-Lieder
# Found ID 42 for Gurre-Lieder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 12 for Michael Nagy
# Found ID 67 for Arnold Schoenberg (1874–1951)
# Gurre-Lieder
# Found ID 42 for Gurre-Lieder
# Found ID 1 for KKL Luzern, Concert Hall
# Found ID 46 for Thomas Quasthoff
# Found ID 67 for Arnold Schoenberg (1874–1951)
# Gurre-Lieder

# %%
test_dataframe
# Out:
#     title venue       date   time artist program  \
# 0      39     1  Tue 13.08  19.30     44      84
# 1      39     1  Tue 13.08  19.30     44      27
# 2      39     1  Tue 13.08  19.30     44      59
# 3      39     1  Tue 13.08  19.30     44      47
# 4      39     1  Tue 13.08  19.30      8      84
# ..    ...   ...        ...    ...    ...     ...
# 281    42     1  Sun 15.09  18.30     51      67
# 282    42     1  Sun 15.09  18.30     61      67
# 283    42     1  Sun 15.09  18.30     71      67
# 284    42     1  Sun 15.09  18.30     12      67
# 285    42     1  Sun 15.09  18.30     46      67
#
#                                             image_link
# 0    https://www.lucernefestival.ch/media/thumbnail...
# 1    https://www.lucernefestival.ch/media/thumbnail...
# 2    https://www.lucernefestival.ch/media/thumbnail...
# 3    https://www.lucernefestival.ch/media/thumbnail...
# 4    https://www.lucernefestival.ch/media/thumbnail...
# ..                                                 ...
# 281  https://www.lucernefestival.ch/media/thumbnail...
# 282  https://www.lucernefestival.ch/media/thumbnail...
# 283  https://www.lucernefestival.ch/media/thumbnail...
# 284  https://www.lucernefestival.ch/media/thumbnail...
# 285  https://www.lucernefestival.ch/media/thumbnail...
#
# [286 rows x 7 columns]

# %%
# Convert the event date strings to the proper format
test_dataframe['date'] = pd.to_datetime(test_dataframe['date'], format='%a %d.%m').dt.strftime('%Y-%m-%d')

# %%
test_dataframe.drop(['event_date'], axis = 1, inplace = True)

# %%
# Convert the 'event_date' column to datetime format
test_dataframe['date'] = pd.to_datetime(test_dataframe['date'])

# Replace the year component in the 'event_date' column
test_dataframe['date'] = test_dataframe['date'].apply(lambda x: x.replace(year=2024).strftime('%Y-%m-%d'))

test_dataframe
# Out:
#     title venue        date   time artist program  \
# 0      39     1  2024-08-13  19.30     44      84
# 1      39     1  2024-08-13  19.30     44      27
# 2      39     1  2024-08-13  19.30     44      59
# 3      39     1  2024-08-13  19.30     44      47
# 4      39     1  2024-08-13  19.30      8      84
# ..    ...   ...         ...    ...    ...     ...
# 281    42     1  2024-09-15  18.30     51      67
# 282    42     1  2024-09-15  18.30     61      67
# 283    42     1  2024-09-15  18.30     71      67
# 284    42     1  2024-09-15  18.30     12      67
# 285    42     1  2024-09-15  18.30     46      67
#
#                                             image_link
# 0    https://www.lucernefestival.ch/media/thumbnail...
# 1    https://www.lucernefestival.ch/media/thumbnail...
# 2    https://www.lucernefestival.ch/media/thumbnail...
# 3    https://www.lucernefestival.ch/media/thumbnail...
# 4    https://www.lucernefestival.ch/media/thumbnail...
# ..                                                 ...
# 281  https://www.lucernefestival.ch/media/thumbnail...
# 282  https://www.lucernefestival.ch/media/thumbnail...
# 283  https://www.lucernefestival.ch/media/thumbnail...
# 284  https://www.lucernefestival.ch/media/thumbnail...
# 285  https://www.lucernefestival.ch/media/thumbnail...
#
# [286 rows x 7 columns]

# %%
# Convert 'artist' and 'program' columns to integer type
test_dataframe['artist'] = test_dataframe['artist'].astype(int)
test_dataframe['program'] = test_dataframe['program'].astype(int)

# %%
type(test_dataframe['artist'])
# Out:
# pandas.core.series.Series

# %%
# Convert the 'date' column to datetime format with specified format
test_dataframe['date'] = pd.to_datetime(test_dataframe['date'], format='%Y-%m-%d')

# %%
# Check for missing or null values in the 'date' column
missing_values = test_dataframe['date'].isnull().sum()
print("Number of missing values in 'date' column:", missing_values)


print(test_dataframe['date'].head())

# Check the unique values in the 'date' column
unique_dates = test_dataframe['date'].unique()
print("Unique dates:", unique_dates)
# Out:
# Number of missing values in 'date' column: 0
# 0   2024-08-13
# 1   2024-08-13
# 2   2024-08-13
# 3   2024-08-13
# 4   2024-08-13
# Name: date, dtype: datetime64[ns]
# Unique dates: <DatetimeArray>
# ['2024-08-13 00:00:00', '2024-08-14 00:00:00', '2024-08-16 00:00:00',
#  '2024-08-17 00:00:00', '2024-08-18 00:00:00', '2024-08-19 00:00:00',
#  '2024-08-20 00:00:00', '2024-08-21 00:00:00', '2024-08-22 00:00:00',
#  '2024-08-23 00:00:00', '2024-08-24 00:00:00', '2024-08-25 00:00:00',
#  '2024-08-27 00:00:00', '2024-08-28 00:00:00', '2024-08-29 00:00:00',
#  '2024-08-30 00:00:00', '2024-08-31 00:00:00', '2024-09-01 00:00:00',
#  '2024-09-02 00:00:00', '2024-09-03 00:00:00', '2024-09-04 00:00:00',
#  '2024-09-05 00:00:00', '2024-09-06 00:00:00', '2024-09-07 00:00:00',
#  '2024-09-08 00:00:00', '2024-09-09 00:00:00', '2024-09-10 00:00:00',
#  '2024-09-11 00:00:00', '2024-09-12 00:00:00', '2024-09-13 00:00:00',
#  '2024-09-14 00:00:00', '2024-09-15 00:00:00']
# Length: 32, dtype: datetime64[ns]

# %%
# Convert the time format in the 'event_time' column
test_dataframe['time'] = test_dataframe['time'].apply(lambda x: f'{int(x.split(".")[0]):02d}:{int(x.split(".")[1]):02d}:00')

# %%
test_dataframe
# Out:
#     title venue       date      time artist program  \
# 0      39     1 2024-08-13  19:30:00     44      84
# 1      39     1 2024-08-13  19:30:00     44      27
# 2      39     1 2024-08-13  19:30:00     44      59
# 3      39     1 2024-08-13  19:30:00     44      47
# 4      39     1 2024-08-13  19:30:00      8      84
# ..    ...   ...        ...       ...    ...     ...
# 281    42     1 2024-09-15  18:30:00     51      67
# 282    42     1 2024-09-15  18:30:00     61      67
# 283    42     1 2024-09-15  18:30:00     71      67
# 284    42     1 2024-09-15  18:30:00     12      67
# 285    42     1 2024-09-15  18:30:00     46      67
#
#                                             image_link
# 0    https://www.lucernefestival.ch/media/thumbnail...
# 1    https://www.lucernefestival.ch/media/thumbnail...
# 2    https://www.lucernefestival.ch/media/thumbnail...
# 3    https://www.lucernefestival.ch/media/thumbnail...
# 4    https://www.lucernefestival.ch/media/thumbnail...
# ..                                                 ...
# 281  https://www.lucernefestival.ch/media/thumbnail...
# 282  https://www.lucernefestival.ch/media/thumbnail...
# 283  https://www.lucernefestival.ch/media/thumbnail...
# 284  https://www.lucernefestival.ch/media/thumbnail...
# 285  https://www.lucernefestival.ch/media/thumbnail...
#
# [286 rows x 7 columns]

# %%
# Convert the DataFrame to a list of tuples
data = [tuple(row) for row in test_dataframe.values]

# Define the insert query
insert_query = """
    INSERT INTO events (title_id, venue_id, event_date, event_time, artist_id, program_id,  image_link)
    VALUES %s
"""

# Execute the insert query with the data
execute_values(cursor, insert_query, data)

# Commit the transaction
conn.commit()
